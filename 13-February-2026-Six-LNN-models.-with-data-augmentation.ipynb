# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/new-kengoh-test-encoder-LNN-data-aug/13-February-2026-Six-LNN-models.-with-data-augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_all_models_comparison.py --augmentation mixed --epochs 20
# Out:
# ...
# RUNNING COMPREHENSIVE COMPARISON WITH MatNILM-Exact Augmentation
# ...
# Augmentation: mixed
# Epochs: 20
# ...
# Loading REDD data with specific splits...
#
# ...
# COMPREHENSIVE MODEL COMPARISON - ALL 6 LNN ARCHITECTURES
# ...
# Augmentation: mixed
# Epochs: 20
# ...
#
# ...
# TESTING ON: DISH WASHER
# ...
#
#   Model: Standard LNN | Parameters: 66,561
#   Augmentation: mixed (prob=0.3)
#     ✅ Standard LNN                        | F1: 0.4876 | MAE: 38.77
#   Model: Advanced LNN | Parameters: 461,825
#   Augmentation: mixed (prob=0.3)
#     ✅ Advanced LNN                        | F1: 0.0000 | MAE: nan
#   Model: Attention LNN | Parameters: 396,033
#   Augmentation: mixed (prob=0.3)
#     ✅ Attention LNN                       | F1: 0.0892 | MAE: 61.74
#   Model: CNN Encoder + Liquid | Parameters: 404,097
#   Augmentation: mixed (prob=0.3)
#     ✅ CNN Encoder + Liquid                | F1: 0.4220 | MAE: 30.53
#   Model: Transformer Encoder + Liquid | Parameters: 1,711,873
#   Augmentation: mixed (prob=0.3)
# ...
