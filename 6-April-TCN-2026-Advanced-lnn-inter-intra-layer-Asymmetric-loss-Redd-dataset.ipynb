# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/fix-data-processing-kengoh-ukdale/6-April-TCN-2026-Advanced-lnn-inter-intra-layer-Asymmetric-loss-Redd-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_tcn_advanced_lnn_two_asymmetric_loss_redd.py
# Out:
# Loading REDD data...
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val   date range: 2011-05-23 10:31:24-04:00   to 2011-05-24 10:31:21-04:00
# Test  date range: 2011-04-18 09:22:12-04:00  to 2011-04-19 18:45:06-04:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing TCN-Advanced-LNN-Two (Asymmetric Loss) on dish washer
#   alpha=0.25  beta=4.0  [FP-penalised]
# ...
#
# Using device: cuda
# Training sequences:   (5740, 100, 1) -> (5740, 1)
# Validation sequences: (5740, 100, 1) -> (5740, 1)
# Test sequences:       (7992, 100, 1) -> (7992, 1)
# Threshold: 10.0W  |  ON: 227  |  OFF: 5513
# Asymmetric BCE -> alpha=0.25  beta=4.0  bce_lambda=0.1  [FP-penalised]
# Starting TCN-Advanced-LNN-Two (Asymmetric Loss) training for dish washer...
#   [dish washer] Epoch   1/80  train=15221.17517  val_mse=13965.55979  F1=0.3498  MAE=24.11  SAE=24.0649  P=0.2145  R=0.9467  lr=1.00e-03
# ...
