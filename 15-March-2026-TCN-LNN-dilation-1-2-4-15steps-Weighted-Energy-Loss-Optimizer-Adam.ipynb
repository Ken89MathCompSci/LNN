# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/kengoh-test-change-optimisers-AdamW/15-March-2026-TCN-LNN-dilation-1-2-4-15steps-Weighted-Energy-Loss-Optimizer-Adam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_tcn_lnn_redd_specific_splits_energy_loss.py
# Out:
# Testing TCN-LNN algorithm on REDD dataset with specific splits...
# Improvements: WeightedMAEEnergyLoss (class-balanced) + energy penalty + post-processing threshold
# Running comprehensive TCN-LNN test on all REDD appliances with specific splits...
# Loading REDD data with specific splits...
# Loading REDD data with specific splits...
# Train data shape: (28800, 5)
# Validation data shape: (28800, 5)
# Test data shape: (40059, 5)
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val date range: 2011-05-23 10:31:24-04:00 to 2011-05-24 10:31:21-04:00
# Test date range: 2011-04-18 09:22:12-04:00 to 2011-04-19 18:45:06-04:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing TCN-LNN on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Class balance for dish washer: 4.0% ON  ->  on_weight = 24.3x
# Training sequences: (5740, 100, 1) -> (5740, 1)
# ...
