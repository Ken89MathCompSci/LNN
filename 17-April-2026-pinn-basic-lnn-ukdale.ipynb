# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/fix-data-processing-kengoh-ukdale/17-April-2026-pinn-basic-lnn-ukdale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_pinn_basic_lnn_ukdale_specific_splits.py
# Out:
# Loading UKDALE data...
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val   date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test  date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
# Using device: cpu
# λ_phys=0.01  ε=50.0 W  hidden=64  dt=0.1
# Train: (2860, 100, 1) → (2860, 4)
# Val:   (2860, 100, 1) → (2860, 4)
# Test:  (2860, 100, 1) → (2860, 4)
# Model parameters: 4,804
# Starting PINN-BasicLNN training (all appliances simultaneously)...
#   Epoch   1/80  train=0.02060 (mse=0.02060 phys=30.38493)  val=0.07146 (mse=0.01182 phys=5.96381)  avgF1=0.2161  avgMAE=52.75  lr=1.00e-03
#     dish washer     F1=0.1339  P=0.0775  R=0.4934  MAE=59.12  SAE=42.8317
#     fridge          F1=0.5292  P=0.3598  R=1.0000  MAE=44.43  SAE=20.5380
#     microwave       F1=0.0132  P=0.0066  R=1.0000  MAE=54.38  SAE=36.6549
# ...
