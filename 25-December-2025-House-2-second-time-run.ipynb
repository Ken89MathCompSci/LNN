# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/kengoh-rerunning/25-December-2025-House-2-second-time-run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Re-preprocess the UK-DALE dataset to address potential data corruption issues
import os

os.chdir('/content/LNN/')
#!python preprocess_ukdale.py
os.chdir('/content/LNN/Source Code')

# %%
# !python data_loader.py
# Out:
# Available appliances:
#   Index 0: Kettle
#   Index 1: Washing_Machine
#   Index 2: Dishwasher
#   Index 3: Fridge
#   Index 4: Microwave
#
# Loading data for appliance index 0...
# Mains data shape: (200000,)
# Appliance data shape: (200000,)
# Appliance name: Kettle
# Training set: (27986, 100, 1), Validation set: (5997, 100, 1), Test set: (5997, 100, 1)
#
# Data loaded successfully!
# Appliance: Kettle
# Training batches: 875
# Validation batches: 188
# Test batches: 188

# %%
import os

#os.chdir('/content/LNN/Source Code')


# Train LSTM model
# !python train_lstm.py
# Out:
# Training LSTM models for 5 appliances in house 2:
#   Index 0: Kettle
#   Index 1: Washing_Machine
#   Index 2: Dishwasher
#   Index 3: Fridge
#   Index 4: Microwave
#
# --------------------------------------------------
# Training LSTM model for Kettle (index 0)
# --------------------------------------------------
#
# Mains data shape: (200000,)
# Appliance data shape: (200000,)
# Appliance name: Kettle
# Training set: (27986, 100, 1), Validation set: (5997, 100, 1), Test set: (5997, 100, 1)
# Starting LSTM training on cuda...
# Epoch 1/50: 100% 875/875 [00:05<00:00, 150.29it/s, loss=4.22]
# Epoch 1/50, Train Loss: 0.973932, Val Loss: 1.212532, Val MAE: 0.25, Val F1: 0.0344
# Model successfully saved to: models/lstm/house2_20251225_165019/Kettle/lstm_model_best.pth
# Model saved to models/lstm/house2_20251225_165019/Kettle/lstm_model_best.pth
# Epoch 2/50: 100% 875/875 [00:05<00:00, 170.37it/s, loss=3.68]
# ...

# %%
# Train GRU model
# !python train_gru.py
# Out:
# Training GRU models for 5 appliances in house 2:
#   Index 0: Kettle
#   Index 1: Washing_Machine
#   Index 2: Dishwasher
#   Index 3: Fridge
#   Index 4: Microwave
#
# --------------------------------------------------
# Training GRU model for Kettle (index 0)
# --------------------------------------------------
#
# Mains data shape: (200000,)
# Appliance data shape: (200000,)
# Appliance name: Kettle
# Training set: (27986, 100, 1), Validation set: (5997, 100, 1), Test set: (5997, 100, 1)
# Starting GRU training on cuda...
# Epoch 1/50: 100% 875/875 [00:03<00:00, 223.31it/s, loss=0.0129]
# Epoch 1/50, Train Loss: 0.972292, Val Loss: 1.214046, Val MAE: 0.25, Val F1: 0.0344
# Model successfully saved to: models/gru/house2_20251225_165951/Kettle/gru_model_best.pth
# Model saved to models/gru/house2_20251225_165951/Kettle/gru_model_best.pth
# Epoch 2/50: 100% 875/875 [00:03<00:00, 242.98it/s, loss=4.03]
# ...

# %%
# Train TCN model
# !python train_tcn.py
# Out:
# Training TCN models for 5 appliances in house 2:
#   Index 0: Kettle
#   Index 1: Washing_Machine
#   Index 2: Dishwasher
#   Index 3: Fridge
#   Index 4: Microwave
#
# --------------------------------------------------
# Training TCN model for Kettle (index 0)
# --------------------------------------------------
#
# Mains data shape: (200000,)
# Appliance data shape: (200000,)
# Appliance name: Kettle
# Training set: (27986, 100, 1), Validation set: (5997, 100, 1), Test set: (5997, 100, 1)
# Starting TCN training on cuda...
# Epoch 1/50: 100% 875/875 [00:03<00:00, 272.86it/s, loss=0.0212]
# Epoch 1/50, Train Loss: 0.969794, Val Loss: 1.212038, Val MAE: 0.27, Val F1: 0.0457
# Model successfully saved to: models/tcn/house2_20251225_170736/Kettle/tcn_model_best.pth
# Model saved to models/tcn/house2_20251225_170736/Kettle/tcn_model_best.pth
# Epoch 2/50: 100% 875/875 [00:02<00:00, 402.82it/s, loss=0.0133]
# ...

# %%
# Train Liquid Neural Network
# !python train_liquidnn.py
# Out:
# Training liquid models for 5 appliances in house 2:
#   Index 0: Kettle
#   Index 1: Washing_Machine
#   Index 2: Dishwasher
#   Index 3: Fridge
#   Index 4: Microwave
#
# --------------------------------------------------
# Training liquid model for Kettle (index 0)
# --------------------------------------------------
#
# Mains data shape: (200000,)
# Appliance data shape: (200000,)
# Appliance name: Kettle
# Training set: (27986, 100, 1), Validation set: (5997, 100, 1), Test set: (5997, 100, 1)
# Starting liquid training on cuda...
# Epoch 1/50: 100% 875/875 [00:46<00:00, 18.96it/s, loss=0.00351]
# Epoch 1/50, Train Loss: 0.976114, Val Loss: 1.226506, Val MAE: 0.19, Val F1: 0.0362
# Model successfully saved to: models/liquid/house2_20251225_171133/Kettle/liquid_model_best.pth
# Model saved to models/liquid/house2_20251225_171133/Kettle/liquid_model_best.pth
# Epoch 2/50: 100% 875/875 [00:46<00:00, 19.00it/s, loss=3.88]
# ...

# %%
# Train Resnet
# !python train_resnet.py
# Out:
# Training ResNet models for 5 appliances in house 2:
#   Index 0: Kettle
#   Index 1: Washing_Machine
#   Index 2: Dishwasher
#   Index 3: Fridge
#   Index 4: Microwave
#
# --------------------------------------------------
# Training ResNet model for Kettle (index 0)
# --------------------------------------------------
#
# Mains data shape: (200000,)
# Appliance data shape: (200000,)
# Appliance name: Kettle
# Training set: (27986, 100, 1), Validation set: (5997, 100, 1), Test set: (5997, 100, 1)
# Starting ResNet training on cuda...
# Epoch 1/50: 100% 875/875 [00:07<00:00, 113.76it/s, loss=3.81]
# Epoch 1/50, Train Loss: 0.988588, Val Loss: 1.216196, Val MAE: 0.30, Val F1: 0.0348
# Model successfully saved to: models/resnet/house2_20251225_212656/Kettle/resnet_model_best.pth
# Model saved to models/resnet/house2_20251225_212656/Kettle/resnet_model_best.pth
# Epoch 2/50: 100% 875/875 [00:07<00:00, 123.46it/s, loss=0.0272]
# ...

# %%
# Train transformer model
# !python train_transformer.py
# Out:
# Training Transformer models for 5 appliances in house 2:
#   Index 0: Kettle
#   Index 1: Washing_Machine
#   Index 2: Dishwasher
#   Index 3: Fridge
#   Index 4: Microwave
#
# --------------------------------------------------
# Training Transformer model for Kettle (index 0)
# --------------------------------------------------
#
# Mains data shape: (200000,)
# Appliance data shape: (200000,)
# Appliance name: Kettle
# Training set: (27986, 100, 1), Validation set: (5997, 100, 1), Test set: (5997, 100, 1)
# Starting Transformer training on cuda...
# Epoch 1/50: 100% 875/875 [00:08<00:00, 98.91it/s, loss=4.02, lr=0.000438]
# Epoch 1/50, Train Loss: 1.003240, Val Loss: 1.245634, Val MAE: 0.19, Val F1: 0.0000
# Model successfully saved to: models/transformer/house2_20251225_213813/Kettle/transformer_model_best.pth
# Model saved to models/transformer/house2_20251225_213813/Kettle/transformer_model_best.pth
# Epoch 2/50: 100% 875/875 [00:08<00:00, 104.03it/s, loss=0.00184, lr=0.0005]
# ...

# %%
# !python evaluate.py
# Out:
# Evaluating models for 5 appliances in house 2:
#   Index 0: Kettle
#   Index 1: Washing_Machine
#   Index 2: Dishwasher
#   Index 3: Fridge
#   Index 4: Microwave
# Using device: cuda
#
# --------------------------------------------------
# Evaluating models for Kettle (index 0)
# --------------------------------------------------
#
# Mains data shape: (200000,)
# Appliance data shape: (200000,)
# Appliance name: Kettle
# Training set: (27986, 100, 1), Validation set: (5997, 100, 1), Test set: (5997, 100, 1)
#
# Evaluating lstm model for Kettle...
# Error loading model from models/lstm/house2_20251225_165019/Kettle/lstm_model_best.pth: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# ...

# %%
# !python compare_models.py
# Out:
# Traceback (most recent call last):
#   File "/content/LNN/Source Code/compare_models.py", line 246, in <module>
#     report_file = generate_effectiveness_report(results_dir)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/LNN/Source Code/compare_models.py", line 119, in generate_effectiveness_report
#     results = load_evaluation_results(results_dir)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/LNN/Source Code/compare_models.py", line 22, in load_evaluation_results
#     raise FileNotFoundError(f"Results file not found: {results_file}")
# FileNotFoundError: Results file not found: results/evaluation_house1_20250320_120000/all_results.json
