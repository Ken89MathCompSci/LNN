# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/fix-data-processing-kengoh-ukdale/2-April-2026-TCN-Advanced-LNN-dilation-1-2-4-15steps-Asymmetric-loss-LNN-Optimizer-Adam-UK-dale-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_tcn_advanced_lnn_asymmetric_loss_ukdale.py
# Out:
# Testing TCN-Advanced-LNN with Asymmetric Loss on UKDALE dataset...
# Loading UKDALE data with specific splits...
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val   date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test  date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing TCN-Advanced-LNN (Asymmetric Loss) on dish washer
#   alpha=0.25  beta=4.0  [FP-penalised]
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences:   (2861, 100, 1) -> (2861, 1)
# Validation sequences: (2861, 100, 1) -> (2861, 1)
# Test sequences:       (2861, 100, 1) -> (2861, 1)
# Asymmetric BCE -> alpha=0.25  beta=4.0  bce_lambda=0.1  (FP-penalised)
# Threshold (raw): 10.0W  |  Threshold (scaled): 0.0042  |  ON: 169  |  OFF: 2692
# Starting TCN-Advanced-LNN (Asymmetric Loss) training for dish washer...
# ...
