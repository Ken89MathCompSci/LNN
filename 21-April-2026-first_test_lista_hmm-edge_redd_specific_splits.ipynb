# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/new-dataset-ampds/21-April-2026-first_test_lista_hmm-edge_redd_specific_splits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !pip install hmmlearn

# %%
# !python test_lista_hmm_edge_redd_specific_splits.py
# Out:
# Loading REDD data with specific splits...
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val   date range: 2011-05-23 10:31:24-04:00 to 2011-05-24 10:31:21-04:00
# Test  date range: 2011-04-18 09:22:12-04:00 to 2011-04-19 18:45:06-04:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# LISTA-HMM-Edge on dish washer
# ...
#
# Device: cuda  |  appliance: dish washer
# n_atoms=64  K=8  context_dim=3  λ_recon=0.1  λ_sparse=0.01  λ_bce=0.3  α_bce=0.5  warmup=15
#   Training HMM on 5740 windows...
#   HMM means (OFF/ON): [3.8499284052264184, 753.281045751634]
#   Building context vectors (HMM posteriors + CUSUM edge density)...
#   Context shape: (5740, 3)
#   Train: (5740, 100, 1)  Val: (5740, 100, 1)  Test: (7992, 100, 1)
#   Model parameters: 91,785
#   Starting training for dish washer...
#   Epoch   1/80  train=0.02032  val=0.01241  F1=0.2683  MAE=28.91  lr=1.00e-03
# ...
