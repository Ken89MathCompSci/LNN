# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/kengoh-change-redd/6_February_2026_REDD_Algorithmns-Second-Run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_lstm_redd_specific_splits.py
# Out:
# Testing LSTM algorithm on REDD dataset with specific splits...
# Running comprehensive LSTM test on all REDD appliances with specific splits...
# Loading REDD data with specific splits...
# Loading REDD data with specific splits...
# Train data shape: (28800, 5)
# Validation data shape: (28800, 5)
# Test data shape: (40059, 5)
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val date range: 2011-05-23 10:31:24-04:00 to 2011-05-24 10:31:21-04:00
# Test date range: 2011-04-18 09:22:12-04:00 to 2011-04-19 18:45:06-04:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing LSTM on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences: (5740, 100, 1) -> (5740, 1)
# Validation sequences: (5740, 100, 1) -> (5740, 1)
# Test sequences: (7992, 100, 1) -> (7992, 1)
# Starting LSTM training for dish washer...
# Epoch 1/50: 100% 180/180 [00:00<00:00, 203.59it/s, loss=23.8]
# ...

# %%
# !python test_redd_specific_splits.py
# Out:
# Testing GRU algorithm on REDD dataset with specific splits...
# Running comprehensive GRU test on all REDD appliances with specific splits...
# Loading REDD data with specific splits...
# Loading REDD data with specific splits...
# Train data shape: (28800, 5)
# Validation data shape: (28800, 5)
# Test data shape: (40059, 5)
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val date range: 2011-05-23 10:31:24-04:00 to 2011-05-24 10:31:21-04:00
# Test date range: 2011-04-18 09:22:12-04:00 to 2011-04-19 18:45:06-04:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing GRU on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences: (5740, 100, 1) -> (5740, 1)
# Validation sequences: (5740, 100, 1) -> (5740, 1)
# Test sequences: (7992, 100, 1) -> (7992, 1)
# Starting GRU training for dish washer...
# Epoch 1/50: 100% 180/180 [00:00<00:00, 216.28it/s, loss=4.31e+4]
# ...

# %%
# !python test_resnet_redd_specific_splits.py
# Out:
# Testing ResNet algorithm on REDD dataset with specific splits...
# Running comprehensive ResNet test on all REDD appliances with specific splits...
# Loading REDD data with specific splits...
# Loading REDD data with specific splits...
# Train data shape: (28800, 5)
# Validation data shape: (28800, 5)
# Test data shape: (40059, 5)
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val date range: 2011-05-23 10:31:24-04:00 to 2011-05-24 10:31:21-04:00
# Test date range: 2011-04-18 09:22:12-04:00 to 2011-04-19 18:45:06-04:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing ResNet on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences: (5740, 100, 1) -> (5740, 1)
# Validation sequences: (5740, 100, 1) -> (5740, 1)
# Test sequences: (7992, 100, 1) -> (7992, 1)
# Starting ResNet training for dish washer...
# Epoch 1/50: 100% 180/180 [00:01<00:00, 97.10it/s, loss=948]
# ...

# %%
# !python test_tcn_redd_specific_splits.py
# Out:
# Testing TCN algorithm on REDD dataset with specific splits...
# Running comprehensive TCN test on all REDD appliances with specific splits...
# Loading REDD data with specific splits...
# Loading REDD data with specific splits...
# Train data shape: (28800, 5)
# Validation data shape: (28800, 5)
# Test data shape: (40059, 5)
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val date range: 2011-05-23 10:31:24-04:00 to 2011-05-24 10:31:21-04:00
# Test date range: 2011-04-18 09:22:12-04:00 to 2011-04-19 18:45:06-04:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing TCN on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences: (5740, 100, 1) -> (5740, 1)
# Validation sequences: (5740, 100, 1) -> (5740, 1)
# Test sequences: (7992, 100, 1) -> (7992, 1)
# Starting TCN training for dish washer...
# Epoch 1/50: 100% 180/180 [00:00<00:00, 202.33it/s, loss=505]
# ...

# %%
# !python test_transformer_redd_specific_splits.py
# Out:
# Testing Transformer algorithm on REDD dataset with specific splits...
# Running comprehensive Transformer test on all REDD appliances with specific splits...
# Loading REDD data with specific splits...
# Loading REDD data with specific splits...
# Train data shape: (28800, 5)
# Validation data shape: (28800, 5)
# Test data shape: (40059, 5)
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val date range: 2011-05-23 10:31:24-04:00 to 2011-05-24 10:31:21-04:00
# Test date range: 2011-04-18 09:22:12-04:00 to 2011-04-19 18:45:06-04:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing Transformer on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences: (5740, 100, 1) -> (5740, 1)
# Validation sequences: (5740, 100, 1) -> (5740, 1)
# Test sequences: (7992, 100, 1) -> (7992, 1)
# Starting Transformer training for dish washer...
# ...

# %%
# !python test_liquidnn_redd_specific_splits.py
# Out:
# Testing Liquid Neural Network algorithm on REDD dataset with specific splits...
# Running comprehensive standard Liquid Neural Network test on all REDD appliances with specific splits...
# Loading REDD data with specific splits...
# Loading REDD data with specific splits...
# Train data shape: (28800, 5)
# Validation data shape: (28800, 5)
# Test data shape: (40059, 5)
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val date range: 2011-05-23 10:31:24-04:00 to 2011-05-24 10:31:21-04:00
# Test date range: 2011-04-18 09:22:12-04:00 to 2011-04-19 18:45:06-04:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing liquid on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences: (5740, 100, 1) -> (5740, 1)
# Validation sequences: (5740, 100, 1) -> (5740, 1)
# Test sequences: (7992, 100, 1) -> (7992, 1)
# Starting liquid training for dish washer...
# ...
