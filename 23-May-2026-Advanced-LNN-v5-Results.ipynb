# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/new-dataset-ampds/23-May-2026-Advanced-LNN-v5-Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_advanced_lnn_v5_ukdale_specific_splits.py
# Out:
# Loading UKDALE data with specific splits...
# Train data shape: (14400, 5)
# Validation data shape: (14400, 5)
# Test data shape: (14400, 5)
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val   date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test  date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Advanced LNN v5 — dish washer
# ...
#
# Appliance: dish washer  |  device: cuda  tau_fast=(0.01, 1.0)  tau_slow=(0.5, 8.0)
#   Training sequences:   (2861, 100, 1)
#   Validation sequences: (2861, 100, 1)
#   Test sequences:       (2861, 100, 1)
#   Parameters: 10,946
#   Training MultiTimescaleLNNModel...
# Epoch 1/80: 100% 90/90 [00:23<00:00,  3.78it/s, loss=0.132]
# Epoch 1/80  train=0.023332  val=0.012321  MAE=79.56  SAE=63.35  F1=0.1491  P=0.0806  R=1.0000
# ...

# %%
# !python test_advanced_lnn_v3_ukdale_specific_splits.py
# Out:
# Advanced LNN v3 on UKDALE dataset with specific splits...
# Loading UKDALE data with specific splits...
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val   date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test  date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Advanced LNN v3 — dish washer
# ...
#
# Using device: cuda
# Training sequences:   (2860, 100, 1) -> (2860, 1)
# Validation sequences: (2860, 100, 1) -> (2860, 1)
# Test sequences:       (2860, 100, 1) -> (2860, 1)
# Model parameters: 37,633
# Starting Advanced LNN v3 training for dish washer...
# Epoch   1/80  train=0.013536  val=0.011635  F1=0.1917  P=0.1060  R=1.0000  MAE=63.49  SAE=48.7325
# Model successfully saved to: models/advanced_lnn_v3_ukdale_specific_20260522_130116/dish_washer/advanced_lnn_v3_ukdale_dish_washer_best.pth
# ...

# %%
# !python test_advanced_lnn_v3_ukdale_specific_splits.py
# Out:
# Advanced LNN v3 on UKDALE dataset with specific splits...
# Loading UKDALE data with specific splits...
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val   date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test  date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Advanced LNN v3 — dish washer
# ...
#
# Using device: cpu
# Training sequences:   (2860, 100, 1) -> (2860, 1)
# Validation sequences: (2860, 100, 1) -> (2860, 1)
# Test sequences:       (2860, 100, 1) -> (2860, 1)
# Model parameters: 37,633
# Starting Advanced LNN v3 training for dish washer...
# Epoch   1/80  train=0.013419  val=0.012087  F1=0.1633  P=0.0889  R=1.0000  MAE=68.92  SAE=54.0184
# Model successfully saved to: models/advanced_lnn_v3_ukdale_specific_20260521_174216/dish_washer/advanced_lnn_v3_ukdale_dish_washer_best.pth
# ...
