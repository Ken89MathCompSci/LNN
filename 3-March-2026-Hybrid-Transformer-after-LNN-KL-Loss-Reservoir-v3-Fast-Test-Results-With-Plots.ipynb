# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/new-kengoh-test-encoder-LNN-data-aug/3-March-2026-Hybrid-Transformer-after-LNN-KL-Loss-Reservoir-v3-Fast-Test-Results-With-Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_hybrid_transformer_lnn_v3.py --appliance fridge --hidden 128
# Out:
# Device: cuda
# Hidden size: 128  |  Max epochs: 80
# Optimiser: Adam  KL_weight=0.1
# Loading REDD data...
#
# ...
#   Hybrid Transformer-LNN — Training
# ...
#
#   ▶  fridge
#   [fridge] Epoch   1/80  train=0.61118  val=1.13388  lr=1.00e-03
#   [fridge] Epoch   2/80  train=0.51807  val=1.34499  lr=1.00e-03
#   [fridge] Epoch   3/80  train=0.45542  val=1.13644  lr=1.00e-03
#   [fridge] Epoch   4/80  train=0.40332  val=1.30800  lr=1.00e-03
#   [fridge] Epoch   5/80  train=0.36891  val=1.25388  lr=1.00e-03
#   [fridge] Epoch   6/80  train=0.38156  val=1.09647  lr=1.00e-03
#   [fridge] Epoch   7/80  train=0.32328  val=0.92133  lr=1.00e-03
#   [fridge] Epoch   8/80  train=0.30243  val=1.19185  lr=1.00e-03
#   [fridge] Epoch   9/80  train=0.27747  val=1.25015  lr=1.00e-03
#   [fridge] Epoch  10/80  train=0.29711  val=1.16391  lr=1.00e-03
#   [fridge] Epoch  11/80  train=0.28465  val=1.20063  lr=1.00e-03
#   [fridge] Epoch  12/80  train=0.26028  val=1.20545  lr=1.00e-03
# ...

# %%
# !python test_hybrid_transformer_lnn_v3.py --appliance microwave --hidden 128
# Out:
# Device: cuda
# Hidden size: 128  |  Max epochs: 80
# Optimiser: Adam  KL_weight=0.1
# Loading REDD data...
#
# ...
#   Hybrid Transformer-LNN — Training
# ...
#
#   ▶  microwave
#   [microwave] Epoch   1/80  train=0.79495  val=2.09412  lr=1.00e-03
#   [microwave] Epoch   2/80  train=0.68790  val=2.13370  lr=1.00e-03
#   [microwave] Epoch   3/80  train=nan  val=nan  lr=1.00e-03
#   [microwave] Epoch   4/80  train=nan  val=nan  lr=1.00e-03
#   [microwave] Epoch   5/80  train=nan  val=nan  lr=1.00e-03
#   [microwave] Epoch   6/80  train=nan  val=nan  lr=1.00e-03
#   [microwave] Epoch   7/80  train=nan  val=nan  lr=1.00e-03
#   [microwave] Epoch   8/80  train=nan  val=nan  lr=1.00e-03
#   [microwave] Epoch   9/80  train=nan  val=nan  lr=1.00e-03
#   [microwave] Epoch  10/80  train=nan  val=nan  lr=5.00e-04
#   [microwave] Epoch  11/80  train=nan  val=nan  lr=5.00e-04
#   [microwave] Epoch  12/80  train=nan  val=nan  lr=5.00e-04
#   [microwave] Epoch  13/80  train=nan  val=nan  lr=5.00e-04
# ...

# %%
# !python test_hybrid_transformer_lnn_v3.py --appliance "dish washer" --hidden 128
# Out:
# Device: cuda
# Hidden size: 128  |  Max epochs: 80
# Optimiser: Adam  KL_weight=0.1
# Loading REDD data...
#
# ...
#   Hybrid Transformer-LNN — Training
# ...
#
#   ▶  dish washer
#   [dish washer] Epoch   1/80  train=0.68365  val=1.02114  lr=1.00e-03
#   [dish washer] Epoch   2/80  train=0.49535  val=0.92883  lr=1.00e-03
#   [dish washer] Epoch   3/80  train=0.38307  val=0.89333  lr=1.00e-03
#   [dish washer] Epoch   4/80  train=0.27264  val=0.99773  lr=1.00e-03
#   [dish washer] Epoch   5/80  train=0.24523  val=0.97188  lr=1.00e-03
#   [dish washer] Epoch   6/80  train=0.27404  val=0.86242  lr=1.00e-03
#   [dish washer] Epoch   7/80  train=0.32030  val=1.00255  lr=1.00e-03
#   [dish washer] Epoch   8/80  train=0.23244  val=0.99222  lr=1.00e-03
#   [dish washer] Epoch   9/80  train=0.23776  val=0.94808  lr=1.00e-03
#   [dish washer] Epoch  10/80  train=0.22722  val=0.93173  lr=1.00e-03
#   [dish washer] Epoch  11/80  train=0.20341  val=0.95048  lr=1.00e-03
# ...

# %%
# !python test_hybrid_transformer_lnn_v3.py --appliance "washer dryer" --hidden 128
# Out:
# Device: cuda
# Hidden size: 128  |  Max epochs: 80
# Optimiser: Adam  KL_weight=0.1
# Loading REDD data...
#
# ...
#   Hybrid Transformer-LNN — Training
# ...
#
#   ▶  washer dryer
#   [washer dryer] Epoch   1/80  train=0.18353  val=0.20687  lr=1.00e-03
#   [washer dryer] Epoch   2/80  train=0.08298  val=0.21997  lr=1.00e-03
#   [washer dryer] Epoch   3/80  train=0.07131  val=0.15126  lr=1.00e-03
#   [washer dryer] Epoch   4/80  train=0.06645  val=0.16950  lr=1.00e-03
#   [washer dryer] Epoch   5/80  train=0.06496  val=0.15848  lr=1.00e-03
#   [washer dryer] Epoch   6/80  train=0.07723  val=0.21233  lr=1.00e-03
#   [washer dryer] Epoch   7/80  train=0.08147  val=0.15922  lr=1.00e-03
#   [washer dryer] Epoch   8/80  train=0.06773  val=0.14954  lr=1.00e-03
#   [washer dryer] Epoch   9/80  train=0.06969  val=0.15091  lr=1.00e-03
#   [washer dryer] Epoch  10/80  train=0.08528  val=1.93608  lr=1.00e-03
#   [washer dryer] Epoch  11/80  train=nan  val=nan  lr=1.00e-03
# ...

# %%
# After all four done:
# !python test_hybrid_transformer_lnn_v3.py --plot
# Out:
# Plot mode — loading saved per-appliance results...
#   Loaded dish washer ← results/hybrid_transformer_lnn/dish_washer.json
#   Loaded fridge ← results/hybrid_transformer_lnn/fridge.json
#   Loaded microwave ← results/hybrid_transformer_lnn/microwave.json
#   Loaded washer dryer ← results/hybrid_transformer_lnn/washer_dryer.json
#
# Generating plots...
#   Saved: results/hybrid_transformer_lnn/training_curves.png
#   Saved: results/hybrid_transformer_lnn/epoch_metrics.png
#   Saved: results/hybrid_transformer_lnn/bar_chart.png
#
# ...
#   F1 — Hybrid Transformer-LNN
# ...
#   Appliance                  Value  (epochs run)
# ───────────────────────────────────────────────────────────────────────────
#   Dish Washer               0.5045  (26 epochs)
#   Fridge                    0.6890  (27 epochs)
#   Microwave                 0.0329  (21 epochs)
#   Washer Dryer              0.1175  (28 epochs)
# ───────────────────────────────────────────────────────────────────────────
# ...
