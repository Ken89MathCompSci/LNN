# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/kengoh-test-change-optimisers-AdamW/8-March-2026-LNN-Model-Results-With-Plots-AdamW-Optimizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_all_models_80epochs.py --optimizer adamw
# Out:
# Loading REDD data...
#
# ...
# LNN COMPREHENSIVE COMPARISON — 80 EPOCHS + LR SCHEDULER
# ...
# Augmentation : none
# Max Epochs   : 80
# Optimizer    : ADAMW
# Appliances   : dish washer, fridge, microwave, washer dryer
# Patience     : 20
# LR Scheduler : ReduceLROnPlateau (factor=0.5, patience=8)
# ...
#
# ...
#   APPLIANCE: DISH WASHER
# ...
#
#   >> Standard LNN
#       Early stop at epoch 47
#      F1=0.4580  MAE=40.94  SAE=39.7350  (epochs=47, params=66,561)
#
#   >> Advanced LNN
#       Early stop at epoch 20
#      F1=0.0000  MAE=nan  SAE=nan  (epochs=20, params=461,825)
#
#   >> Attention LNN
#       Early stop at epoch 21
#      F1=0.4401  MAE=41.44  SAE=40.5845  (epochs=21, params=396,033)
#
#   >> CNN + LNN
#       Early stop at epoch 23
#      F1=0.5368  MAE=36.92  SAE=35.8203  (epochs=23, params=404,097)
#
#   >> Transformer + LNN
#       Early stop at epoch 21
#      F1=0.4862  MAE=37.24  SAE=37.1513  (epochs=21, params=922,113)
#
#   >> Bidir + LNN
#       Early stop at epoch 35
# ...
