# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/fix-data-processing-kengoh-ukdale/22-March-2026-Base-Models-Optimizer-Adam-UK-dale-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_gru_ukdale_specific_splits.py
# Out:
# Testing GRU on UKDALE dataset with specific splits...
# Loading UKDALE data with specific splits...
# Train data shape: (14400, 5)
# Validation data shape: (14400, 5)
# Test data shape: (14400, 5)
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing GRU on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences:   (2860, 100, 1) -> (2860, 1)
# Validation sequences: (2860, 100, 1) -> (2860, 1)
# Test sequences:       (2860, 100, 1) -> (2860, 1)
# Starting GRU training for dish washer...
# Epoch 1/80: 100% 90/90 [00:00<00:00, 136.58it/s, loss=0.000155]
# Epoch 1/80, Train Loss: 0.015415, Val Loss: 0.012263, Val MAE: 40.62, Val SAE: 33.37, Val F1: 0.1143, Val Precision: 0.0606, Val Recall: 1.0000
# ...

# %%
# !python test_tcn_ukdale_specific_splits.py
# Out:
# Testing TCN on UKDALE dataset with specific splits...
# Loading UKDALE data with specific splits...
# Train data shape: (14400, 5)
# Validation data shape: (14400, 5)
# Test data shape: (14400, 5)
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing TCN on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences:   (2860, 100, 1) -> (2860, 1)
# Validation sequences: (2860, 100, 1) -> (2860, 1)
# Test sequences:       (2860, 100, 1) -> (2860, 1)
# Starting TCN training for dish washer...
# Epoch 1/80: 100% 90/90 [00:00<00:00, 115.99it/s, loss=0.0635]
# Epoch 1/80, Train Loss: 0.013805, Val Loss: 0.010091, Val MAE: 51.25, Val SAE: 42.08, Val F1: 0.0959, Val Precision: 0.0503, Val Recall: 1.0000
# ...

# %%
# !python test_resnet_ukdale_specific_splits.py
# Out:
# Testing ResNet on UKDALE dataset with specific splits...
# Loading UKDALE data with specific splits...
# Train data shape: (14400, 5)
# Validation data shape: (14400, 5)
# Test data shape: (14400, 5)
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing ResNet on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences:   (2860, 100, 1) -> (2860, 1)
# Validation sequences: (2860, 100, 1) -> (2860, 1)
# Test sequences:       (2860, 100, 1) -> (2860, 1)
# Starting ResNet training for dish washer...
# Epoch 1/80: 100% 90/90 [00:01<00:00, 69.42it/s, loss=0.00632]
# Epoch 1/80, Train Loss: 0.087148, Val Loss: 0.013233, Val MAE: 171.17, Val SAE: 123.93, Val F1: 0.1737, Val Precision: 0.1279, Val Recall: 0.2708
# ...

# %%
# !python test_lstm_ukdale_specific_splits.py
# Out:
# Testing LSTM on UKDALE dataset with specific splits...
# Loading UKDALE data with specific splits...
# Train data shape: (14400, 5)
# Validation data shape: (14400, 5)
# Test data shape: (14400, 5)
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing LSTM on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences:   (2860, 100, 1) -> (2860, 1)
# Validation sequences: (2860, 100, 1) -> (2860, 1)
# Test sequences:       (2860, 100, 1) -> (2860, 1)
# Starting LSTM training for dish washer...
# Epoch 1/80: 100% 90/90 [00:00<00:00, 131.76it/s, loss=0.000536]
# Epoch 1/80, Train Loss: 0.015236, Val Loss: 0.012367, Val MAE: 75.31, Val SAE: 69.12, Val F1: 0.0959, Val Precision: 0.0503, Val Recall: 1.0000
# ...

# %%
# !python test_transformer_ukdale_specific_splits.py
# Out:
# Testing Transformer on UKDALE dataset with specific splits...
# Loading UKDALE data with specific splits...
# Train data shape: (14400, 5)
# Validation data shape: (14400, 5)
# Test data shape: (14400, 5)
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing Transformer on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences:   (2860, 100, 1) -> (2860, 1)
# Validation sequences: (2860, 100, 1) -> (2860, 1)
# Test sequences:       (2860, 100, 1) -> (2860, 1)
# Starting Transformer training for dish washer...
# Epoch 1/80: 100% 90/90 [00:01<00:00, 71.73it/s, loss=0.065]
# Epoch 1/80, Train Loss: 0.371725, Val Loss: 0.011180, Val MAE: 135.02, Val SAE: 129.81, Val F1: 0.0959, Val Precision: 0.0503, Val Recall: 1.0000
# ...
