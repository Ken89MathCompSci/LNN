# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/new-kengoh-test-encoder-LNN-data-aug/14-February-2026-Six-LNN-models.-without-data-augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_all_models_comparison.py
# Out:
# ...
# RUNNING COMPREHENSIVE COMPARISON WITHOUT Augmentation (Baseline)
# ...
# Augmentation: none
# Epochs: 20
# ...
# Loading REDD data with specific splits...
#
# ...
# COMPREHENSIVE MODEL COMPARISON - ALL 6 LNN ARCHITECTURES
# ...
# Augmentation: none
# Epochs: 20
# ...
#
# ...
# TESTING ON: DISH WASHER
# ...
#
#   Model: Standard LNN | Parameters: 66,561
#     ✅ Standard LNN                        | F1: 0.0865 | MAE: 51.66 | SAE: 50.0138
#   Model: Advanced LNN | Parameters: 461,825
#     ✅ Advanced LNN                        | F1: 0.0000 | MAE: nan | SAE: nan
#   Model: Attention LNN | Parameters: 396,033
#     ✅ Attention LNN                       | F1: 0.5352 | MAE: 37.43 | SAE: 36.7517
#   Model: CNN Encoder + Liquid | Parameters: 404,097
#     ✅ CNN Encoder + Liquid                | F1: 0.1974 | MAE: 39.25 | SAE: 39.0081
#   Model: Transformer Encoder + Liquid | Parameters: 1,711,873
#     ✅ Transformer Encoder + Liquid        | F1: 0.1029 | MAE: 55.39 | SAE: 55.0917
# ...
