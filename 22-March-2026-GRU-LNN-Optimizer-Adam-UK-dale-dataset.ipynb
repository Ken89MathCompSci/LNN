# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/fix-data-processing-kengoh-ukdale/22-March-2026-GRU-LNN-Optimizer-Adam-UK-dale-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_gru_lnn_ukdale_specific_splits.py
# Out:
# Testing GRU-LNN on UKDALE dataset with specific splits...
# Loading UKDALE data with specific splits...
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val   date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test  date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing GRU-LNN on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences:   (2860, 100, 1) -> (2860, 1)
# Validation sequences: (2860, 100, 1) -> (2860, 1)
# Test sequences:       (2860, 100, 1) -> (2860, 1)
# Starting GRU-LNN training for dish washer...
# Epoch 1/80: 100% 90/90 [00:08<00:00, 10.82it/s, loss=0.0679]
# Epoch 1/80, Train Loss: 0.015130, Val Loss: 0.015771, Val MAE: 209.04, Val SAE: 197.47, Val F1: 0.0959, Val Precision: 0.0503, Val Recall: 1.0000
# ...
