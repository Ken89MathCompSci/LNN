# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/fix-data-processing-kengoh-ukdale/6-April-TCN-2026-Advanced-lnn-inter-intra-layer-Redd-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_tcn_advanced_lnn_redd_specific_splits.py
# Out:
# Loading REDD data...
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val   date range: 2011-05-23 10:31:24-04:00   to 2011-05-24 10:31:21-04:00
# Test  date range: 2011-04-18 09:22:12-04:00  to 2011-04-19 18:45:06-04:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing TCN-Advanced-LNN (MSE Loss) on dish washer
# ...
#
# Using device: cuda
# Training sequences:   (5740, 100, 1) -> (5740, 1)
# Validation sequences: (5740, 100, 1) -> (5740, 1)
# Test sequences:       (7992, 100, 1) -> (7992, 1)
# Threshold: 10.0W  |  ON: 227  |  OFF: 5513
# Starting TCN-Advanced-LNN (MSE Loss) training for dish washer...
#   [dish washer] Epoch   1/80  train=15394.86666  val_mse=14340.98467  F1=0.0908  MAE=24.16  SAE=24.0722  P=0.0543  R=0.2756  lr=1.00e-03
#   [dish washer] Epoch   2/80  train=14823.22124  val_mse=13535.58194  F1=0.2831  MAE=25.39  SAE=25.1501  P=0.1676  R=0.9111  lr=1.00e-03
# ...
