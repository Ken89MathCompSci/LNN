# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/kengoh-test-change-optimisers-AdamW/20-March-2026-TCN-LNN-dilation-1-2-4-15steps-intra-LNN-Optimizer-Adam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python tcn_advanced_lnn_two_redd_specific_splits.py
# Out:
# Testing TCN + AdvancedLiquidNetworkModelTwo on REDD dataset...
# Loading REDD data with specific splits...
# Train data shape: (28800, 5)
# Validation data shape: (28800, 5)
# Test data shape: (40059, 5)
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val date range: 2011-05-23 10:31:24-04:00 to 2011-05-24 10:31:21-04:00
# Test date range: 2011-04-18 09:22:12-04:00 to 2011-04-19 18:45:06-04:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# TCN-AdvLNN2: dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences:   (5740, 100, 1) -> (5740, 1)
# Validation sequences: (5740, 100, 1) -> (5740, 1)
# Test sequences:       (7992, 100, 1) -> (7992, 1)
# Starting TCN-AdvLNN2 training for dish washer...
# Epoch 1/80: 100% 180/180 [00:59<00:00,  3.02it/s, loss=0.0041]
# Epoch 1/80, Train Loss: 0.041558, Val Loss: 0.023874, Val MAE: 58.79, Val SAE: 56.97, Val F1: 0.0754
# ...
