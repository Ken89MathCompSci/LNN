# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/new-kengoh-test-encoder-LNN-data-aug/3-March-2026-Hybrid-Transformer-LNN-Reservoir-v2-Fast-Test-Results-With-Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# Run one appliance at a time (128 hidden = ~4x faster than 256)
# !python test_hybrid_transformer_lnn_v2.py --appliance fridge --hidden 128
# Out:
# Device: cuda
# Hidden size: 128  |  Max epochs: 80
# Architecture: Input Embedding → CNN (ReLU+MaxPool) → Adaptive PE → LiquidTransformer (LNN in Q,K + GLU FFN) → FC
# Loading REDD data...
#
# ...
#   Hybrid Transformer-LNN v2 — Training
# ...
#
#   ▶  fridge
#   [fridge] Epoch   1/80  train=0.63383  val=0.95265  lr=1.00e-03
#   [fridge] Epoch   2/80  train=0.49728  val=1.02954  lr=1.00e-03
#   [fridge] Epoch   3/80  train=0.41490  val=1.24099  lr=1.00e-03
#   [fridge] Epoch   4/80  train=0.36007  val=0.87954  lr=1.00e-03
#   [fridge] Epoch   5/80  train=0.34558  val=1.06532  lr=1.00e-03
#   [fridge] Epoch   6/80  train=0.29504  val=0.86239  lr=1.00e-03
#   [fridge] Epoch   7/80  train=0.28223  val=1.16029  lr=1.00e-03
#   [fridge] Epoch   8/80  train=0.26904  val=1.11379  lr=1.00e-03
#   [fridge] Epoch   9/80  train=0.25689  val=1.01741  lr=1.00e-03
#   [fridge] Epoch  10/80  train=0.21680  val=1.11222  lr=1.00e-03
#   [fridge] Epoch  11/80  train=0.22834  val=0.94580  lr=1.00e-03
# ...

# %%
# !python test_hybrid_transformer_lnn_v2.py --appliance microwave --hidden 128
# Out:
# Device: cuda
# Hidden size: 128  |  Max epochs: 80
# Architecture: Input Embedding → CNN (ReLU+MaxPool) → Adaptive PE → LiquidTransformer (LNN in Q,K + GLU FFN) → FC
# Loading REDD data...
#
# ...
#   Hybrid Transformer-LNN v2 — Training
# ...
#
#   ▶  microwave
#   [microwave] Epoch   1/80  train=0.75063  val=2.09628  lr=1.00e-03
#   [microwave] Epoch   2/80  train=0.53433  val=2.10497  lr=1.00e-03
#   [microwave] Epoch   3/80  train=0.34178  val=2.10849  lr=1.00e-03
#   [microwave] Epoch   4/80  train=0.24624  val=2.05084  lr=1.00e-03
#   [microwave] Epoch   5/80  train=0.26958  val=1.95288  lr=1.00e-03
#   [microwave] Epoch   6/80  train=0.37649  val=1.81467  lr=1.00e-03
#   [microwave] Epoch   7/80  train=0.21895  val=1.92721  lr=1.00e-03
#   [microwave] Epoch   8/80  train=0.26837  val=2.19379  lr=1.00e-03
#   [microwave] Epoch   9/80  train=0.31159  val=2.09015  lr=1.00e-03
#   [microwave] Epoch  10/80  train=0.21365  val=1.80046  lr=1.00e-03
# ...

# %%
# !python test_hybrid_transformer_lnn_v2.py --appliance "dish washer" --hidden 128
# Out:
# Device: cuda
# Hidden size: 128  |  Max epochs: 80
# Architecture: Input Embedding → CNN (ReLU+MaxPool) → Adaptive PE → LiquidTransformer (LNN in Q,K + GLU FFN) → FC
# Loading REDD data...
#
# ...
#   Hybrid Transformer-LNN v2 — Training
# ...
#
#   ▶  dish washer
#   [dish washer] Epoch   1/80  train=0.51052  val=1.08151  lr=1.00e-03
#   [dish washer] Epoch   2/80  train=0.26810  val=0.98637  lr=1.00e-03
#   [dish washer] Epoch   3/80  train=0.20546  val=0.89608  lr=1.00e-03
#   [dish washer] Epoch   4/80  train=0.19622  val=0.88697  lr=1.00e-03
#   [dish washer] Epoch   5/80  train=0.21155  val=1.07063  lr=1.00e-03
#   [dish washer] Epoch   6/80  train=0.19152  val=0.95130  lr=1.00e-03
#   [dish washer] Epoch   7/80  train=0.16374  val=0.98156  lr=1.00e-03
#   [dish washer] Epoch   8/80  train=0.14553  val=1.03646  lr=1.00e-03
#   [dish washer] Epoch   9/80  train=0.14532  val=0.97795  lr=1.00e-03
#   [dish washer] Epoch  10/80  train=0.16930  val=1.06421  lr=1.00e-03
# ...

# %%
# !python test_hybrid_transformer_lnn_v2.py --appliance "washer dryer" --hidden 128
# Out:
# Device: cuda
# Hidden size: 128  |  Max epochs: 80
# Architecture: Input Embedding → CNN (ReLU+MaxPool) → Adaptive PE → LiquidTransformer (LNN in Q,K + GLU FFN) → FC
# Loading REDD data...
#
# ...
#   Hybrid Transformer-LNN v2 — Training
# ...
#
#   ▶  washer dryer
#   [washer dryer] Epoch   1/80  train=0.15470  val=0.16224  lr=1.00e-03
#   [washer dryer] Epoch   2/80  train=0.07143  val=0.15431  lr=1.00e-03
#   [washer dryer] Epoch   3/80  train=0.06626  val=0.14657  lr=1.00e-03
#   [washer dryer] Epoch   4/80  train=0.06050  val=0.15166  lr=1.00e-03
#   [washer dryer] Epoch   5/80  train=0.06423  val=0.20253  lr=1.00e-03
#   [washer dryer] Epoch   6/80  train=0.06416  val=0.15731  lr=1.00e-03
#   [washer dryer] Epoch   7/80  train=0.05607  val=0.52834  lr=1.00e-03
#   [washer dryer] Epoch   8/80  train=0.06658  val=0.21903  lr=1.00e-03
#   [washer dryer] Epoch   9/80  train=0.05553  val=0.17056  lr=1.00e-03
#   [washer dryer] Epoch  10/80  train=0.05388  val=0.16246  lr=1.00e-03
# ...

# %%
# After all four done, regenerate plots
# !python test_hybrid_transformer_lnn_v2.py --plot
# Out:
# Plot mode — loading saved per-appliance results...
#   Loaded dish washer ← results/hybrid_transformer_lnn_v2/dish_washer.json
#   Loaded fridge ← results/hybrid_transformer_lnn_v2/fridge.json
#   Loaded microwave ← results/hybrid_transformer_lnn_v2/microwave.json
#   Loaded washer dryer ← results/hybrid_transformer_lnn_v2/washer_dryer.json
#
# Generating plots...
#   Saved: results/hybrid_transformer_lnn_v2/training_curves.png
#   Saved: results/hybrid_transformer_lnn_v2/epoch_metrics.png
#   Saved: results/hybrid_transformer_lnn_v2/bar_chart.png
#
# ...
#   F1 — Hybrid Transformer-LNN v2
# ...
#   Appliance                  Value  (epochs run)
# ───────────────────────────────────────────────────────────────────────────
#   Dish Washer               0.6151  (33 epochs)
#   Fridge                    0.6910  (34 epochs)
#   Microwave                 0.1190  (47 epochs)
#   Washer Dryer              0.0725  (23 epochs)
# ───────────────────────────────────────────────────────────────────────────
# ...
