# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/fix-data-processing-kengoh-ukdale/23-March-2026-TEST-Advanced-LNN-Optimizer-Adam-UKDALE-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_advanced_lnn_ukdale_specific_splits.py
# Out:
# Testing Advanced-LNN on UKDALE dataset with specific splits...
# Loading UKDALE data with specific splits...
# Train data shape: (14400, 5)
# Validation data shape: (14400, 5)
# Test data shape: (14400, 5)
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing Advanced-LNN on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences:   (2861, 100, 1) -> (2861, 1)
# Validation sequences: (2861, 100, 1) -> (2861, 1)
# Test sequences:       (2861, 100, 1) -> (2861, 1)
# Starting Advanced-LNN training for dish washer...
# Epoch 1/80: 100% 90/90 [00:27<00:00,  3.31it/s, loss=0.00405]
# ...
