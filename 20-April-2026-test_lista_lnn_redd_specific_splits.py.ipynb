# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/fix-data-processing-kengoh-ukdale/20-April-2026-test_lista_lnn_redd_specific_splits.py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_lista_lnn_redd_specific_splits.py
# Out:
# Loading REDD data with specific splits...
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val   date range: 2011-05-23 10:31:24-04:00 to 2011-05-24 10:31:21-04:00
# Test  date range: 2011-04-18 09:22:12-04:00 to 2011-04-19 18:45:06-04:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# LISTA-LNN on dish washer
# ...
#
# Device: cuda  |  appliance: dish washer
# n_atoms=64  K=8  λ_recon=0.1  λ_sparse=0.01  λ_bce=0.3  α_bce=0.5  warmup=15
# Train: (5740, 100, 1) → (5740, 1)
# Val:   (5740, 100, 1) → (5740, 1)
# Test:  (7992, 100, 1) → (7992, 1)
# Model parameters: 91,457
# Starting LISTA-LNN training for dish washer...
#   Epoch   1/80  train=0.02822  val=0.02075  F1=0.2025  MAE=37.15  lr=1.00e-03
# Model successfully saved to: models/lista_lnn_redd_specific_test_20260419_180940/dish_washer/lista_lnn_redd_dish_washer_best.pth
#   Epoch   2/80  train=0.02192  val=0.02051  F1=0.1954  MAE=34.12  lr=1.00e-03
# ...
