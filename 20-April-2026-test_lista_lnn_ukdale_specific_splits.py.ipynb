# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/fix-data-processing-kengoh-ukdale/20-April-2026-test_lista_lnn_ukdale_specific_splits.py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_lista_lnn_ukdale_specific_splits.py
# Out:
# Loading UKDALE data with specific splits...
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val   date range: 2014-12-07 00:00:00 to 2014-12-07 23:59:54
# Test  date range: 2014-08-24 00:00:00 to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# LISTA-LNN on dish washer
# ...
#
# Device: cuda  |  appliance: dish washer
# n_atoms=64  K=8  λ_recon=0.1  λ_sparse=0.01  λ_bce=0.3  α_bce=1.0  warmup=15
# Train: (2860, 100, 1) → (2860, 1)
# Val:   (2860, 100, 1) → (2860, 1)
# Test:  (2860, 100, 1) → (2860, 1)
# Model parameters: 91,457
# Starting LISTA-LNN training for dish washer...
#   Epoch   1/80  train=0.01597  val=0.01425  F1=0.1009  MAE=79.57  lr=1.00e-03
# Model successfully saved to: models/lista_lnn_ukdale_specific_test_20260420_131121/dish_washer/lista_lnn_ukdale_dish_washer_best.pth
#   Epoch   2/80  train=0.01197  val=0.01077  F1=0.2099  MAE=49.63  lr=1.00e-03
# ...
