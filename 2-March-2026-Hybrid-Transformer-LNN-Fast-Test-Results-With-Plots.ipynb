# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/new-kengoh-test-encoder-LNN-data-aug/2-March-2026-Hybrid-Transformer-LNN-Fast-Test-Results-With-Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_hybrid_transformer_lnn.py
# Out:
# Device: cuda
# Hidden size: 256  |  Max epochs: 80
# Loading REDD data...
#
# ...
#   Hybrid Transformer-LNN — Training
# ...
#
#   ▶  dish washer
#   [dish washer] Epoch   1/80  train=0.87592  val=0.86595  lr=1.00e-03
#   [dish washer] Epoch   2/80  train=0.86758  val=0.74393  lr=1.00e-03
#   [dish washer] Epoch   3/80  train=0.83775  val=0.85849  lr=1.00e-03
#   [dish washer] Epoch   4/80  train=0.90492  val=1.00104  lr=1.00e-03
#   [dish washer] Epoch   5/80  train=0.98960  val=0.93325  lr=1.00e-03
#   [dish washer] Epoch   6/80  train=1.00908  val=0.92947  lr=1.00e-03
#   [dish washer] Epoch   7/80  train=0.83416  val=0.30411  lr=1.00e-03
#   [dish washer] Epoch   8/80  train=0.63240  val=0.57236  lr=1.00e-03
#   [dish washer] Epoch   9/80  train=0.68173  val=0.94298  lr=1.00e-03
#   [dish washer] Epoch  10/80  train=1.04324  val=0.93152  lr=1.00e-03
#   [dish washer] Epoch  11/80  train=0.86752  val=0.93307  lr=1.00e-03
# ...
