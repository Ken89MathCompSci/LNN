# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/new-kengoh-test-encoder-LNN-data-aug/14-February-2026-Six-LNN-models.-with-data-augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_all_models_comparison.py --augmentation mixed --epochs 20
# Out:
# ...
# RUNNING COMPREHENSIVE COMPARISON WITH MatNILM-Exact Augmentation
# ...
# Augmentation: mixed
# Epochs: 20
# ...
# Loading REDD data with specific splits...
#
# ...
# COMPREHENSIVE MODEL COMPARISON - ALL 6 LNN ARCHITECTURES
# ...
# Augmentation: mixed
# Epochs: 20
# ...
#
# ...
# TESTING ON: DISH WASHER
# ...
#
#   Model: Standard LNN | Parameters: 66,561
#   Augmentation: mixed (prob=0.3)
#     ✅ Standard LNN                        | F1: 0.4434 | MAE: 29.51 | SAE: 28.3296
#   Model: Advanced LNN | Parameters: 461,825
#   Augmentation: mixed (prob=0.3)
#     ✅ Advanced LNN                        | F1: 0.0000 | MAE: nan | SAE: nan
#   Model: Attention LNN | Parameters: 396,033
#   Augmentation: mixed (prob=0.3)
#     ✅ Attention LNN                       | F1: 0.3223 | MAE: 40.03 | SAE: 39.5570
#   Model: CNN Encoder + Liquid | Parameters: 404,097
#   Augmentation: mixed (prob=0.3)
#     ✅ CNN Encoder + Liquid                | F1: 0.1027 | MAE: 49.64 | SAE: 49.0698
# ...
