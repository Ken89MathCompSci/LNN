# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/fix-data-processing-kengoh-ukdale/8-April-2026-TCN-Advanced-lnn-inter-intra-layer-Asymmetric-loss-Ukdale-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_tcn_advanced_lnn_two_asymmetric_loss_ukdale.py
# Out:
# Loading UKDALE data...
# Train date range: 2014-11-09 00:00:00 to 2014-11-09 23:59:54
# Val   date range: 2014-12-07 00:00:00   to 2014-12-07 23:59:54
# Test  date range: 2014-08-24 00:00:00  to 2014-08-24 23:59:54
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing TCN-Advanced-LNN-Two (Asymmetric Loss) on dish washer
#   alpha=0.25  beta=4.0  [FP-penalised]
# ...
#
# Using device: cuda
# Training sequences:   (2860, 100, 1) -> (2860, 1)
# Validation sequences: (2860, 100, 1) -> (2860, 1)
# Test sequences:       (2860, 100, 1) -> (2860, 1)
# Threshold: 10.0W  |  ON: 169  |  OFF: 2691
# Asymmetric BCE -> alpha=0.25  beta=4.0  bce_lambda=0.1  [FP-penalised]
# Starting TCN-Advanced-LNN-Two (Asymmetric Loss) training for dish washer...
#   [dish washer] Epoch   1/80  train=85577.39497  val_mse=95104.12549  F1=0.0000  MAE=36.28  SAE=23.0498  P=0.0000  R=0.0000  lr=1.00e-03
# ...
