# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/kengoh-test-change-optimisers-AdamW/5-March-2026-Base-Model-Results-With-Plots-AdamW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python run_baseline_models_80epochs.py --model gru --optimizer adamw
# Out:
# Device: cuda
# Loading REDD data...
#
# ######################################################################
# #  GRU
# ######################################################################
#
#   ▶  dish washer
#   [GRU | dish washer] Epoch   1/80  train=15073.58575  val=13752.87916  lr=1.00e-03
#   [GRU | dish washer] Epoch   2/80  train=14664.46841  val=13349.17124  lr=1.00e-03
#   [GRU | dish washer] Epoch   3/80  train=14413.68702  val=14110.97402  lr=1.00e-03
#   [GRU | dish washer] Epoch   4/80  train=14618.14695  val=13463.74474  lr=1.00e-03
#   [GRU | dish washer] Epoch   5/80  train=14131.34580  val=12329.62355  lr=1.00e-03
#   [GRU | dish washer] Epoch   6/80  train=13750.39954  val=12693.18282  lr=1.00e-03
#   [GRU | dish washer] Epoch   7/80  train=13314.88139  val=13747.08189  lr=1.00e-03
#   [GRU | dish washer] Epoch   8/80  train=12973.37094  val=13588.55856  lr=1.00e-03
#   [GRU | dish washer] Epoch   9/80  train=12273.40244  val=13883.08939  lr=1.00e-03
# ...

# %%
# !python run_baseline_models_80epochs.py --model lstm --optimizer adamw
# Out:
# Device: cuda
# Loading REDD data...
#
# ######################################################################
# #  LSTM
# ######################################################################
#
#   ▶  dish washer
#   [LSTM | dish washer] Epoch   1/80  train=15015.73287  val=13591.65596  lr=1.00e-03
#   [LSTM | dish washer] Epoch   2/80  train=14582.48298  val=13379.12431  lr=1.00e-03
#   [LSTM | dish washer] Epoch   3/80  train=14569.49057  val=13300.07469  lr=1.00e-03
#   [LSTM | dish washer] Epoch   4/80  train=14306.61952  val=13091.53557  lr=1.00e-03
#   [LSTM | dish washer] Epoch   5/80  train=14299.36231  val=12786.65540  lr=1.00e-03
#   [LSTM | dish washer] Epoch   6/80  train=14575.15102  val=13146.60881  lr=1.00e-03
#   [LSTM | dish washer] Epoch   7/80  train=14227.18454  val=13061.49325  lr=1.00e-03
#   [LSTM | dish washer] Epoch   8/80  train=14263.46167  val=12679.35630  lr=1.00e-03
#   [LSTM | dish washer] Epoch   9/80  train=14059.15316  val=13302.68711  lr=1.00e-03
# ...

# %%
# !python run_baseline_models_80epochs.py --model resnet --optimizer adamw
# Out:
# Device: cuda
# Loading REDD data...
#
# ######################################################################
# #  ResNet
# ######################################################################
#
#   ▶  dish washer
#   [ResNet | dish washer] Epoch   1/80  train=15062.06941  val=13016.26477  lr=1.00e-03
#   [ResNet | dish washer] Epoch   2/80  train=14618.21874  val=13527.40659  lr=1.00e-03
#   [ResNet | dish washer] Epoch   3/80  train=14771.52821  val=13314.14638  lr=1.00e-03
#   [ResNet | dish washer] Epoch   4/80  train=14762.49397  val=13123.54853  lr=1.00e-03
#   [ResNet | dish washer] Epoch   5/80  train=14533.31702  val=13419.35925  lr=1.00e-03
#   [ResNet | dish washer] Epoch   6/80  train=14342.73470  val=12775.23532  lr=1.00e-03
#   [ResNet | dish washer] Epoch   7/80  train=14514.46201  val=12395.72476  lr=1.00e-03
#   [ResNet | dish washer] Epoch   8/80  train=14270.14797  val=12484.12691  lr=1.00e-03
# ...

# %%
# !python run_baseline_models_80epochs.py --model tcn --optimizer adamw
# Out:
# Device: cuda
# Loading REDD data...
#
# ######################################################################
# #  TCN
# ######################################################################
#
#   ▶  dish washer
#   [TCN | dish washer] Epoch   1/80  train=14520.33488  val=13870.26532  lr=1.00e-03
#   [TCN | dish washer] Epoch   2/80  train=13315.26149  val=12198.40429  lr=1.00e-03
#   [TCN | dish washer] Epoch   3/80  train=12382.86365  val=10382.41784  lr=1.00e-03
#   [TCN | dish washer] Epoch   4/80  train=12024.77146  val=12742.35895  lr=1.00e-03
#   [TCN | dish washer] Epoch   5/80  train=11552.73368  val=11996.71259  lr=1.00e-03
#   [TCN | dish washer] Epoch   6/80  train=10683.68967  val=13106.60164  lr=1.00e-03
#   [TCN | dish washer] Epoch   7/80  train=9782.36793  val=9829.06633  lr=1.00e-03
#   [TCN | dish washer] Epoch   8/80  train=9292.63299  val=13935.34063  lr=1.00e-03
#   [TCN | dish washer] Epoch   9/80  train=9850.46861  val=11863.68166  lr=1.00e-03
# ...

# %%
# !python run_baseline_models_80epochs.py --model transformer --optimizer adamw
# Out:
# Device: cuda
# Loading REDD data...
#
# ######################################################################
# #  Transformer
# ######################################################################
#
#   ▶  dish washer
#   [Transformer | dish washer] Epoch   1/80  train=13348.61148  val=14089.84864  lr=1.00e-03
#   [Transformer | dish washer] Epoch   2/80  train=6634.20029  val=14137.63390  lr=1.00e-03
#   [Transformer | dish washer] Epoch   3/80  train=8236.76517  val=14910.74788  lr=1.00e-03
#   [Transformer | dish washer] Epoch   4/80  train=6006.09774  val=13798.23828  lr=1.00e-03
#   [Transformer | dish washer] Epoch   5/80  train=5254.78276  val=14001.84842  lr=1.00e-03
#   [Transformer | dish washer] Epoch   6/80  train=7305.78063  val=14079.60026  lr=1.00e-03
#   [Transformer | dish washer] Epoch   7/80  train=7344.85870  val=14169.49076  lr=1.00e-03
#   [Transformer | dish washer] Epoch   8/80  train=6267.73169  val=14234.64619  lr=1.00e-03
# ...

# %%
# !python run_baseline_models_80epochs.py --plot
# Out:
# Plot mode — loading saved results...
#   Loaded GRU from results/baseline_80epochs/gru.json
#   Loaded LSTM from results/baseline_80epochs/lstm.json
#   Loaded ResNet from results/baseline_80epochs/resnet.json
#   Loaded TCN from results/baseline_80epochs/tcn.json
#   Loaded Transformer from results/baseline_80epochs/transformer.json
#
# Generating graphs...
#   Saved → results/baseline_80epochs/mae_per_appliance.png
#   Saved → results/baseline_80epochs/sae_per_appliance.png
#   Saved → results/baseline_80epochs/f1_per_appliance.png
#   Saved → results/baseline_80epochs/summary_all_metrics.png
#   Saved → results/baseline_80epochs/f1_heatmap.png
#   Saved → results/baseline_80epochs/epoch_metrics_all_models.png
#
# ...
#   F1 Comparison
# ...
#   Model           Dish Washer     Fridge          Microwave       Washer Dryer    Avg
# ────────────────────────────────────────────────────────────────────────────────
# ...
