# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/kengoh-test-change-optimisers-AdamW/9-March-Test-intra-inter-Advanced-LNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_all_models_80epochs.py --model advanced_lnn_two
# Out:
# Loading REDD data...
#
# ...
# LNN COMPREHENSIVE COMPARISON — 80 EPOCHS + LR SCHEDULER
# ...
# Augmentation : none
# Max Epochs   : 80
# Optimizer    : ADAM
# Appliances   : dish washer, fridge, microwave, washer dryer
# Models       : Advanced LNN Two
# Patience     : 20
# LR Scheduler : ReduceLROnPlateau (factor=0.5, patience=8)
# ...
#
# ...
#   APPLIANCE: DISH WASHER
# ...
#
#   >> Advanced LNN Two
#       Early stop at epoch 26
#      F1=0.4189  MAE=31.85  SAE=30.7567  (epochs=26, params=463,873)
#
# ...
#   APPLIANCE: FRIDGE
# ...
#
#   >> Advanced LNN Two
#       Early stop at epoch 26
#      F1=0.5474  MAE=60.54  SAE=57.9852  (epochs=26, params=463,873)
#
# ...
#   APPLIANCE: MICROWAVE
# ...
#
#   >> Advanced LNN Two
#       Early stop at epoch 21
#      F1=0.0336  MAE=32.89  SAE=29.5810  (epochs=21, params=463,873)
#
# ...
#   APPLIANCE: WASHER DRYER
# ...
#
#   >> Advanced LNN Two
#       Early stop at epoch 48
#      F1=0.0836  MAE=42.60  SAE=42.6450  (epochs=48, params=463,873)
#
# ...
# FINAL COMPARISON — F1 SCORES
# ...
