# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/new-kengoh-test-encoder-LNN-data-aug/1-March-2026-LNN-Model-Results-With-Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_all_models_80epochs.py
# Out:
# Loading REDD data...
#
# ...
# LNN COMPREHENSIVE COMPARISON — 80 EPOCHS + LR SCHEDULER
# ...
# Augmentation : none
# Max Epochs   : 80
# Patience     : 20
# LR Scheduler : ReduceLROnPlateau (factor=0.5, patience=8)
# ...
#
# ...
#   APPLIANCE: DISH WASHER
# ...
#
#   >> Standard LNN
#       Early stop at epoch 21
#      F1=0.1008  MAE=58.87  SAE=56.9407  (epochs=21, params=66,561)
#
#   >> Advanced LNN
#       Early stop at epoch 20
#      F1=0.0000  MAE=nan  SAE=nan  (epochs=20, params=461,825)
#
#   >> Attention LNN
#       Early stop at epoch 28
#      F1=0.5126  MAE=32.05  SAE=30.9714  (epochs=28, params=396,033)
#
#   >> CNN + LNN
#       Early stop at epoch 23
#      F1=0.4452  MAE=35.51  SAE=34.9428  (epochs=23, params=404,097)
#
#   >> Transformer + LNN
#       Early stop at epoch 22
#      F1=0.4395  MAE=41.90  SAE=41.7473  (epochs=22, params=922,113)
#
#   >> Bidir + LNN
#       Early stop at epoch 31
#      F1=0.6136  MAE=33.74  SAE=32.7467  (epochs=31, params=264,193)
#
# ...
#   APPLIANCE: FRIDGE
# ...
#
# ...
