# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/new-kengoh-test-encoder-LNN-data-aug/3-March-2026-Hybrid-Transformer-after-LNN-v4-Fast-Test-Results-With-Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_hybrid_transformer_lnn_v4.py --appliance fridge --hidden 128
# Out:
# Device: cuda
# Hidden size: 128  |  Max epochs: 80
# Optimiser: Adam
# Loading REDD data...
#
# ...
#   Hybrid Transformer-LNN v4 — Training
# ...
#
#   ▶  fridge
#   [fridge] Epoch   1/80  train=0.60232  val=1.49446  lr=1.00e-03
#   [fridge] Epoch   2/80  train=0.52551  val=1.04826  lr=1.00e-03
#   [fridge] Epoch   3/80  train=0.48471  val=0.79982  lr=1.00e-03
#   [fridge] Epoch   4/80  train=0.44206  val=0.90947  lr=1.00e-03
#   [fridge] Epoch   5/80  train=0.38642  val=1.08374  lr=1.00e-03
#   [fridge] Epoch   6/80  train=0.37043  val=1.04888  lr=1.00e-03
#   [fridge] Epoch   7/80  train=0.34624  val=0.81826  lr=1.00e-03
#   [fridge] Epoch   8/80  train=0.30927  val=1.06582  lr=1.00e-03
#   [fridge] Epoch   9/80  train=0.28788  val=1.06740  lr=1.00e-03
#   [fridge] Epoch  10/80  train=0.32845  val=0.91770  lr=1.00e-03
#   [fridge] Epoch  11/80  train=0.31163  val=1.12006  lr=1.00e-03
#   [fridge] Epoch  12/80  train=0.27735  val=1.03097  lr=5.00e-04
# ...

# %%
# !python test_hybrid_transformer_lnn_v4.py --appliance microwave --hidden 128
# Out:
# Device: cuda
# Hidden size: 128  |  Max epochs: 80
# Optimiser: Adam
# Loading REDD data...
#
# ...
#   Hybrid Transformer-LNN v4 — Training
# ...
#
#   ▶  microwave
#   [microwave] Epoch   1/80  train=0.79478  val=2.03628  lr=1.00e-03
#   [microwave] Epoch   2/80  train=0.92477  val=2.04416  lr=1.00e-03
#   [microwave] Epoch   3/80  train=0.87338  val=2.16386  lr=1.00e-03
#   [microwave] Epoch   4/80  train=0.98244  val=2.06679  lr=1.00e-03
#   [microwave] Epoch   5/80  train=0.99214  val=2.03402  lr=1.00e-03
#   [microwave] Epoch   6/80  train=0.97582  val=2.00342  lr=1.00e-03
#   [microwave] Epoch   7/80  train=0.96973  val=2.07339  lr=1.00e-03
#   [microwave] Epoch   8/80  train=0.99268  val=2.09540  lr=1.00e-03
#   [microwave] Epoch   9/80  train=0.99006  val=2.06636  lr=1.00e-03
#   [microwave] Epoch  10/80  train=0.98829  val=2.05199  lr=1.00e-03
#   [microwave] Epoch  11/80  train=0.98563  val=2.01911  lr=1.00e-03
#   [microwave] Epoch  12/80  train=0.99107  val=2.04044  lr=1.00e-03
# ...

# %%
# !python test_hybrid_transformer_lnn_v4.py --appliance "dish washer" --hidden 128
# Out:
# Device: cuda
# Hidden size: 128  |  Max epochs: 80
# Optimiser: Adam
# Loading REDD data...
#
# ...
#   Hybrid Transformer-LNN v4 — Training
# ...
#
#   ▶  dish washer
#   [dish washer] Epoch   1/80  train=0.66619  val=0.98450  lr=1.00e-03
#   [dish washer] Epoch   2/80  train=0.45593  val=1.33059  lr=1.00e-03
#   [dish washer] Epoch   3/80  train=0.30192  val=1.24220  lr=1.00e-03
#   [dish washer] Epoch   4/80  train=0.23743  val=1.18796  lr=1.00e-03
#   [dish washer] Epoch   5/80  train=0.21173  val=0.82346  lr=1.00e-03
#   [dish washer] Epoch   6/80  train=0.23883  val=0.97628  lr=1.00e-03
#   [dish washer] Epoch   7/80  train=0.24850  val=1.07443  lr=1.00e-03
#   [dish washer] Epoch   8/80  train=0.19057  val=0.37641  lr=1.00e-03
#   [dish washer] Epoch   9/80  train=0.21312  val=1.06185  lr=1.00e-03
#   [dish washer] Epoch  10/80  train=0.30457  val=0.51957  lr=1.00e-03
#   [dish washer] Epoch  11/80  train=0.29201  val=0.67135  lr=1.00e-03
# ...

# %%
# !python test_hybrid_transformer_lnn_v4.py --appliance "washer dryer" --hidden 128
# Out:
# Device: cuda
# Hidden size: 128  |  Max epochs: 80
# Optimiser: Adam
# Loading REDD data...
#
# ...
#   Hybrid Transformer-LNN v4 — Training
# ...
#
#   ▶  washer dryer
#   [washer dryer] Epoch   1/80  train=0.20163  val=0.21721  lr=1.00e-03
#   [washer dryer] Epoch   2/80  train=0.08299  val=0.17339  lr=1.00e-03
#   [washer dryer] Epoch   3/80  train=0.07372  val=0.17977  lr=1.00e-03
#   [washer dryer] Epoch   4/80  train=0.07038  val=0.20484  lr=1.00e-03
#   [washer dryer] Epoch   5/80  train=0.06712  val=0.15974  lr=1.00e-03
#   [washer dryer] Epoch   6/80  train=0.06235  val=0.15713  lr=1.00e-03
#   [washer dryer] Epoch   7/80  train=0.06561  val=0.15663  lr=1.00e-03
#   [washer dryer] Epoch   8/80  train=0.06044  val=0.20102  lr=1.00e-03
#   [washer dryer] Epoch   9/80  train=0.08283  val=0.17903  lr=1.00e-03
#   [washer dryer] Epoch  10/80  train=0.08459  val=0.18143  lr=1.00e-03
#   [washer dryer] Epoch  11/80  train=0.07861  val=0.20035  lr=1.00e-03
# ...

# %%
# After all four done:
# !python test_hybrid_transformer_lnn_v4.py --plot
# Out:
# Plot mode — loading saved per-appliance results...
#   Loaded dish washer ← results/hybrid_transformer_lnn_v4/dish_washer.json
#   Loaded fridge ← results/hybrid_transformer_lnn_v4/fridge.json
#   Loaded microwave ← results/hybrid_transformer_lnn_v4/microwave.json
#   Loaded washer dryer ← results/hybrid_transformer_lnn_v4/washer_dryer.json
#
# Generating plots...
#   Saved: results/hybrid_transformer_lnn_v4/training_curves.png
#   Saved: results/hybrid_transformer_lnn_v4/epoch_metrics.png
#   Saved: results/hybrid_transformer_lnn_v4/bar_chart.png
#
# ...
#   F1 — Hybrid Transformer-LNN v4
# ...
#   Appliance                  Value  (epochs run)
# ───────────────────────────────────────────────────────────────────────────
#   Dish Washer               0.5322  (48 epochs)
#   Fridge                    0.6677  (23 epochs)
#   Microwave                 0.3380  (77 epochs)
#   Washer Dryer              0.1191  (27 epochs)
# ───────────────────────────────────────────────────────────────────────────
# ...
