# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/fix-data-processing-kengoh-ukdale/5-April-2026-Advanced-lnn-inter-intra-layer-Redd-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_advanced_lnn_two_redd_specific_splits.py
# Out:
# Testing Advanced-LNN-Two (inter+intra LayerNorm) on REDD dataset with specific splits...
# Loading REDD data...
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val   date range: 2011-05-23 10:31:24-04:00 to 2011-05-24 10:31:21-04:00
# Test  date range: 2011-04-18 09:22:12-04:00 to 2011-04-19 18:45:06-04:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
#
# ...
# Testing Advanced-LNN-Two on dish washer
# ...
#
# Using device: cuda
# Creating sequences for dish washer...
# Training sequences:   (5741, 100, 1) -> (5741, 1)
# Validation sequences: (5741, 100, 1) -> (5741, 1)
# Test sequences:       (7992, 100, 1) -> (7992, 1)
# Starting Advanced-LNN-Two (inter+intra LayerNorm) training for dish washer...
# Epoch 1/80: 100% 180/180 [00:57<00:00,  3.14it/s, loss=0.00427]
# Epoch 1/80, Train Loss: 0.029727, Val Loss: 0.020302, Val MAE: 48.47, Val SAE: 47.04, Val F1: 0.1513, Val Precision: 0.0820, Val Recall: 0.9778
# ...
