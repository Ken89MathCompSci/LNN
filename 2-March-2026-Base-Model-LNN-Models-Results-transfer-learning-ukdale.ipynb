# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/master/2-March-2026-Base-Model-LNN-Models-Results-transfer-learning-ukdale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python evaluate_on_ukdale.py --model gru
# Out:
# Device: cuda
#
# Loading data...
# REDD appliances            : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# UK-DALE appliances         : ['dish washer', 'fridge', 'kettle', 'microwave', 'toaster', 'washer dryer']
# Testing on (intersection)  : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# Skipped (no REDD training) : ['kettle', 'toaster']
#
# #################################################################
# #  GRU  [baseline]  (train: REDD → test: UK-DALE)
# #################################################################
#
#   ▶  dish washer
#     Early stop epoch 29
#   ✅ GRU                    | dish washer     | F1=0.0000  MAE=18.71  SAE=18.0481
#
#   ▶  fridge
#     Early stop epoch 43
#   ✅ GRU                    | fridge          | F1=0.6225  MAE=48.60  SAE=32.2479
#
#   ▶  microwave
#   ✅ GRU                    | microwave       | F1=0.0320  MAE=23.20  SAE=16.3138
#
#   ▶  washer dryer
#   ✅ GRU                    | washer dryer    | F1=0.3815  MAE=36.61  SAE=29.6830
#
#   JSON saved → results/ukdale_eval/gru.json
#
# Still missing: ['lstm', 'resnet', 'tcn', 'transformer', 'standard_lnn', 'advanced_lnn', 'attention_lnn', 'cnn_encoder', 'transformer_lnn', 'bidirectional_lnn']
# Run those models then:  !python evaluate_on_ukdale.py --plot

# %%
# !python evaluate_on_ukdale.py --model lstm
# Out:
# Device: cuda
#
# Loading data...
# REDD appliances            : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# UK-DALE appliances         : ['dish washer', 'fridge', 'kettle', 'microwave', 'toaster', 'washer dryer']
# Testing on (intersection)  : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# Skipped (no REDD training) : ['kettle', 'toaster']
#
# #################################################################
# #  LSTM  [baseline]  (train: REDD → test: UK-DALE)
# #################################################################
#
#   ▶  dish washer
#     Early stop epoch 41
#   ✅ LSTM                   | dish washer     | F1=0.0869  MAE=23.89  SAE=21.1895
#
#   ▶  fridge
#     Early stop epoch 59
#   ✅ LSTM                   | fridge          | F1=0.5706  MAE=50.66  SAE=16.0117
#
#   ▶  microwave
#     Early stop epoch 37
#   ✅ LSTM                   | microwave       | F1=0.0000  MAE=7.70  SAE=5.8528
#
#   ▶  washer dryer
#   ✅ LSTM                   | washer dryer    | F1=0.2671  MAE=37.26  SAE=31.5198
#
#   JSON saved → results/ukdale_eval/lstm.json
#
# Still missing: ['resnet', 'tcn', 'transformer', 'standard_lnn', 'advanced_lnn', 'attention_lnn', 'cnn_encoder', 'transformer_lnn', 'bidirectional_lnn']
# Run those models then:  !python evaluate_on_ukdale.py --plot

# %%
# !python evaluate_on_ukdale.py --model resnet
# Out:
# Device: cuda
#
# Loading data...
# REDD appliances            : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# UK-DALE appliances         : ['dish washer', 'fridge', 'kettle', 'microwave', 'toaster', 'washer dryer']
# Testing on (intersection)  : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# Skipped (no REDD training) : ['kettle', 'toaster']
#
# #################################################################
# #  ResNet  [baseline]  (train: REDD → test: UK-DALE)
# #################################################################
#
#   ▶  dish washer
#   ✅ ResNet                 | dish washer     | F1=0.0094  MAE=25.16  SAE=22.2434
#
#   ▶  fridge
#     Early stop epoch 35
#   ✅ ResNet                 | fridge          | F1=0.5997  MAE=39.59  SAE=12.3050
#
#   ▶  microwave
#     Early stop epoch 35
#   ✅ ResNet                 | microwave       | F1=0.0437  MAE=38.75  SAE=32.0898
#
#   ▶  washer dryer
#     Early stop epoch 39
#   ✅ ResNet                 | washer dryer    | F1=0.1294  MAE=52.17  SAE=51.2197
#
#   JSON saved → results/ukdale_eval/resnet.json
#
# Still missing: ['tcn', 'transformer', 'standard_lnn', 'advanced_lnn', 'attention_lnn', 'cnn_encoder', 'transformer_lnn', 'bidirectional_lnn']
# Run those models then:  !python evaluate_on_ukdale.py --plot

# %%
# !python evaluate_on_ukdale.py --model tcn
# Out:
# Device: cuda
#
# Loading data...
# REDD appliances            : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# UK-DALE appliances         : ['dish washer', 'fridge', 'kettle', 'microwave', 'toaster', 'washer dryer']
# Testing on (intersection)  : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# Skipped (no REDD training) : ['kettle', 'toaster']
#
# #################################################################
# #  TCN  [baseline]  (train: REDD → test: UK-DALE)
# #################################################################
#
#   ▶  dish washer
#     Early stop epoch 25
#   ✅ TCN                    | dish washer     | F1=0.0614  MAE=18.76  SAE=18.0685
#
#   ▶  fridge
#     Early stop epoch 31
#   ✅ TCN                    | fridge          | F1=0.6113  MAE=46.85  SAE=24.2782
#
#   ▶  microwave
#     Early stop epoch 47
#   ✅ TCN                    | microwave       | F1=0.0382  MAE=9.03  SAE=5.8806
#
#   ▶  washer dryer
#   ✅ TCN                    | washer dryer    | F1=0.2988  MAE=38.59  SAE=29.9081
#
#   JSON saved → results/ukdale_eval/tcn.json
#
# Still missing: ['transformer', 'standard_lnn', 'advanced_lnn', 'attention_lnn', 'cnn_encoder', 'transformer_lnn', 'bidirectional_lnn']
# Run those models then:  !python evaluate_on_ukdale.py --plot

# %%
# !python evaluate_on_ukdale.py --model transformer
# Out:
# Device: cuda
#
# Loading data...
# REDD appliances            : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# UK-DALE appliances         : ['dish washer', 'fridge', 'kettle', 'microwave', 'toaster', 'washer dryer']
# Testing on (intersection)  : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# Skipped (no REDD training) : ['kettle', 'toaster']
#
# #################################################################
# #  Transformer  [baseline]  (train: REDD → test: UK-DALE)
# #################################################################
#
#   ▶  dish washer
#     Early stop epoch 23
#   ✅ Transformer            | dish washer     | F1=0.0793  MAE=19.13  SAE=18.0876
#
#   ▶  fridge
#     Early stop epoch 31
#   ✅ Transformer            | fridge          | F1=0.7172  MAE=37.14  SAE=16.4157
#
#   ▶  microwave
#     Early stop epoch 22
#   ✅ Transformer            | microwave       | F1=0.0297  MAE=12.40  SAE=6.4431
#
#   ▶  washer dryer
#     Early stop epoch 29
#   ✅ Transformer            | washer dryer    | F1=0.3058  MAE=34.77  SAE=30.8468
#
#   JSON saved → results/ukdale_eval/transformer.json
#
# Still missing: ['standard_lnn', 'advanced_lnn', 'attention_lnn', 'cnn_encoder', 'transformer_lnn', 'bidirectional_lnn']
# Run those models then:  !python evaluate_on_ukdale.py --plot

# %%
# !python evaluate_on_ukdale.py --model standard_lnn
# Out:
# Device: cuda
#
# Loading data...
# REDD appliances            : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# UK-DALE appliances         : ['dish washer', 'fridge', 'kettle', 'microwave', 'toaster', 'washer dryer']
# Testing on (intersection)  : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# Skipped (no REDD training) : ['kettle', 'toaster']
#
# #################################################################
# #  Standard LNN  [lnn]  (train: REDD → test: UK-DALE)
# #################################################################
#
#   ▶  dish washer
#     Early stop epoch 29
#   ✅ Standard LNN           | dish washer     | F1=0.9710  MAE=2130.64  SAE=2130.1699
#
#   ▶  fridge
#     Early stop epoch 27
#   ✅ Standard LNN           | fridge          | F1=0.9612  MAE=2934.23  SAE=2910.0820
#
#   ▶  microwave
#     Early stop epoch 23
#   ✅ Standard LNN           | microwave       | F1=0.5952  MAE=793.98  SAE=780.7384
#
#   ▶  washer dryer
#     Early stop epoch 28
#   ✅ Standard LNN           | washer dryer    | F1=0.2325  MAE=24340.49  SAE=24345.4688
#
#   JSON saved → results/ukdale_eval/standard_lnn.json
#
# Still missing: ['advanced_lnn', 'attention_lnn', 'cnn_encoder', 'transformer_lnn', 'bidirectional_lnn']
# Run those models then:  !python evaluate_on_ukdale.py --plot

# %%
# !python evaluate_on_ukdale.py --model advanced_lnn
# Out:
# Device: cuda
#
# Loading data...
# REDD appliances            : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# UK-DALE appliances         : ['dish washer', 'fridge', 'kettle', 'microwave', 'toaster', 'washer dryer']
# Testing on (intersection)  : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# Skipped (no REDD training) : ['kettle', 'toaster']
#
# #################################################################
# #  Advanced LNN  [lnn]  (train: REDD → test: UK-DALE)
# #################################################################
#
#   ▶  dish washer
#     Early stop epoch 20
#   ✅ Advanced LNN           | dish washer     | F1=0.0000  MAE=nan  SAE=nan
#
#   ▶  fridge
#     Early stop epoch 20
#   ✅ Advanced LNN           | fridge          | F1=0.0000  MAE=nan  SAE=nan
#
#   ▶  microwave
#     Early stop epoch 20
#   ✅ Advanced LNN           | microwave       | F1=0.0000  MAE=nan  SAE=nan
#
#   ▶  washer dryer
#     Early stop epoch 20
#   ✅ Advanced LNN           | washer dryer    | F1=0.0000  MAE=nan  SAE=nan
#
#   JSON saved → results/ukdale_eval/advanced_lnn.json
#
# Still missing: ['attention_lnn', 'cnn_encoder', 'transformer_lnn', 'bidirectional_lnn']
# Run those models then:  !python evaluate_on_ukdale.py --plot

# %%
# !python evaluate_on_ukdale.py --model attention_lnn
# Out:
# Device: cuda
#
# Loading data...
# REDD appliances            : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# UK-DALE appliances         : ['dish washer', 'fridge', 'kettle', 'microwave', 'toaster', 'washer dryer']
# Testing on (intersection)  : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# Skipped (no REDD training) : ['kettle', 'toaster']
#
# #################################################################
# #  Attention LNN  [lnn]  (train: REDD → test: UK-DALE)
# #################################################################
#
#   ▶  dish washer
#     Early stop epoch 21
#   ✅ Attention LNN          | dish washer     | F1=0.9813  MAE=2139.85  SAE=2139.9324
#
#   ▶  fridge
#     Early stop epoch 31
#   ✅ Attention LNN          | fridge          | F1=0.9704  MAE=2931.48  SAE=2917.7556
#
#   ▶  microwave
#     Early stop epoch 21
#   ✅ Attention LNN          | microwave       | F1=0.5778  MAE=797.05  SAE=781.1308
#
#   ▶  washer dryer
#     Early stop epoch 31
#   ✅ Attention LNN          | washer dryer    | F1=0.8901  MAE=24332.49  SAE=24330.1367
#
#   JSON saved → results/ukdale_eval/attention_lnn.json
#
# Still missing: ['cnn_encoder', 'transformer_lnn', 'bidirectional_lnn']
# Run those models then:  !python evaluate_on_ukdale.py --plot

# %%
# !python evaluate_on_ukdale.py --model cnn_encoder
# Out:
# Device: cuda
#
# Loading data...
# REDD appliances            : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# UK-DALE appliances         : ['dish washer', 'fridge', 'kettle', 'microwave', 'toaster', 'washer dryer']
# Testing on (intersection)  : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# Skipped (no REDD training) : ['kettle', 'toaster']
#
# #################################################################
# #  CNN+LNN  [lnn]  (train: REDD → test: UK-DALE)
# #################################################################
#
#   ▶  dish washer
#     Early stop epoch 30
#   ✅ CNN+LNN                | dish washer     | F1=0.1674  MAE=2156.88  SAE=2157.2917
#
#   ▶  fridge
#     Early stop epoch 36
#   ✅ CNN+LNN                | fridge          | F1=0.9622  MAE=2931.47  SAE=2908.7024
#
#   ▶  microwave
#     Early stop epoch 65
#   ✅ CNN+LNN                | microwave       | F1=0.4753  MAE=861.41  SAE=777.5967
#
#   ▶  washer dryer
#     Early stop epoch 42
#   ✅ CNN+LNN                | washer dryer    | F1=0.9964  MAE=24321.69  SAE=24319.3457
#
#   JSON saved → results/ukdale_eval/cnn_encoder.json
#
# Still missing: ['transformer_lnn', 'bidirectional_lnn']
# Run those models then:  !python evaluate_on_ukdale.py --plot

# %%
# next session:
# !python evaluate_on_ukdale.py --model transformer_lnn
# Out:
# Device: cuda
#
# Loading data...
# REDD appliances            : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# UK-DALE appliances         : ['dish washer', 'fridge', 'kettle', 'microwave', 'toaster', 'washer dryer']
# Testing on (intersection)  : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# Skipped (no REDD training) : ['kettle', 'toaster']
#
# #################################################################
# #  Transformer+LNN  [lnn]  (train: REDD → test: UK-DALE)
# #################################################################
#
#   ▶  dish washer
#     Early stop epoch 25
#   ✅ Transformer+LNN        | dish washer     | F1=0.4972  MAE=2155.16  SAE=2155.6172
#
#   ▶  fridge
#     Early stop epoch 46
#   ✅ Transformer+LNN        | fridge          | F1=0.9999  MAE=2930.64  SAE=2907.8171
#
#   ▶  microwave
#     Early stop epoch 22
#   ✅ Transformer+LNN        | microwave       | F1=0.1697  MAE=800.86  SAE=801.0173
#
#   ▶  washer dryer
#     Early stop epoch 30
#   ✅ Transformer+LNN        | washer dryer    | F1=0.9997  MAE=24273.90  SAE=24277.1250
#
#   JSON saved → results/ukdale_eval/transformer_lnn.json
#
# Still missing: ['bidirectional_lnn']
# Run those models then:  !python evaluate_on_ukdale.py --plot

# %%
# next session:
# !python evaluate_on_ukdale.py --model bidirectional_lnn
# Out:
# Device: cuda
#
# Loading data...
# REDD appliances            : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# UK-DALE appliances         : ['dish washer', 'fridge', 'kettle', 'microwave', 'toaster', 'washer dryer']
# Testing on (intersection)  : ['dish washer', 'fridge', 'microwave', 'washer dryer']
# Skipped (no REDD training) : ['kettle', 'toaster']
#
# #################################################################
# #  Bidir+LNN  [lnn]  (train: REDD → test: UK-DALE)
# #################################################################
#
#   ▶  dish washer
#     Early stop epoch 27
#   ✅ Bidir+LNN              | dish washer     | F1=0.1119  MAE=2166.32  SAE=2166.7258
#
#   ▶  fridge
#     Early stop epoch 26
#   ✅ Bidir+LNN              | fridge          | F1=0.9823  MAE=2930.49  SAE=2911.6643
#
#   ▶  microwave
#     Early stop epoch 32
#   ✅ Bidir+LNN              | microwave       | F1=0.6302  MAE=799.11  SAE=776.5153
#
#   ▶  washer dryer
#     Early stop epoch 25
#   ✅ Bidir+LNN              | washer dryer    | F1=0.2672  MAE=24374.95  SAE=24367.5352
#
#   JSON saved → results/ukdale_eval/bidirectional_lnn.json
#
# All models complete — generating combined graphs...
#   Loaded GRU from results/ukdale_eval/gru.json
#   Loaded LSTM from results/ukdale_eval/lstm.json
#   Loaded ResNet from results/ukdale_eval/resnet.json
#   Loaded TCN from results/ukdale_eval/tcn.json
#   Loaded Transformer from results/ukdale_eval/transformer.json
#   Loaded Standard LNN from results/ukdale_eval/standard_lnn.json
#   Loaded Advanced LNN from results/ukdale_eval/advanced_lnn.json
#   Loaded Attention LNN from results/ukdale_eval/attention_lnn.json
#   Loaded CNN+LNN from results/ukdale_eval/cnn_encoder.json
#   Loaded Transformer+LNN from results/ukdale_eval/transformer_lnn.json
#   Loaded Bidir+LNN from results/ukdale_eval/bidirectional_lnn.json
#
# Generating graphs...
#   Saved → results/ukdale_eval/mae_comparison.png
#   Saved → results/ukdale_eval/sae_comparison.png
#   Saved → results/ukdale_eval/f1_comparison.png
#
# ===========================================================================
#   F1 — Train: REDD  /  Test: UK-DALE
# ===========================================================================
#   Model                 Dish Washer   Fridge        Microwave     Washer Dryer  Avg
# ───────────────────────────────────────────────────────────────────────────
#   GRU                   0.0000        0.6225        0.0320        0.3815        0.2590
#   LSTM                  0.0869        0.5706        0.0000        0.2671        0.2312
#   ResNet                0.0094        0.5997        0.0437        0.1294        0.1956
#   TCN                   0.0614        0.6113        0.0382        0.2988        0.2524
#   Transformer           0.0793        0.7172        0.0297        0.3058        0.2830
#   Standard LNN          0.9710        0.9612        0.5952        0.2325        0.6900
#   Advanced LNN          0.0000        0.0000        0.0000        0.0000        0.0000
#   Attention LNN         0.9813        0.9704        0.5778        0.8901        0.8549
#   CNN+LNN               0.1674        0.9622        0.4753        0.9964        0.6503
#   Transformer+LNN       0.4972        0.9999        0.1697        0.9997        0.6666
#   Bidir+LNN             0.1119        0.9823        0.6302        0.2672        0.4979
#
# ===========================================================================
#   MAE — Train: REDD  /  Test: UK-DALE
# ===========================================================================
#   Model                 Dish Washer   Fridge        Microwave     Washer Dryer  Avg
# ───────────────────────────────────────────────────────────────────────────
#   GRU                   18.7102       48.5950       23.2031       36.6114       31.7799
#   LSTM                  23.8905       50.6561       7.7002        37.2581       29.8762
#   ResNet                25.1582       39.5930       38.7464       52.1681       38.9165
#   TCN                   18.7602       46.8484       9.0258        38.5928       28.3068
#   Transformer           19.1322       37.1403       12.4029       34.7747       25.8625
#   Standard LNN          2130.6350     2934.2258     793.9761      24340.4883    7549.8313
# /content/LNN/evaluate_on_ukdale.py:369: RuntimeWarning: Mean of empty slice
#   avg  = np.nanmean(vals)
#   Advanced LNN          nan           nan           nan           nan           nan
#   Attention LNN         2139.8513     2931.4846     797.0479      24332.4922    7550.2190
#   CNN+LNN               2156.8811     2931.4702     861.4076      24321.6855    7567.8611
#   Transformer+LNN       2155.1602     2930.6392     800.8639      24273.8965    7540.1399
#   Bidir+LNN             2166.3164     2930.4905     799.1103      24374.9473    7567.7161
#
# ===========================================================================
#   SAE — Train: REDD  /  Test: UK-DALE
# ===========================================================================
#   Model                 Dish Washer   Fridge        Microwave     Washer Dryer  Avg
# ───────────────────────────────────────────────────────────────────────────
#   GRU                   18.0481       32.2479       16.3138       29.6830       24.0732
#   LSTM                  21.1895       16.0117       5.8528        31.5198       18.6434
#   ResNet                22.2434       12.3050       32.0898       51.2197       29.4645
#   TCN                   18.0685       24.2782       5.8806        29.9081       19.5339
#   Transformer           18.0876       16.4157       6.4431        30.8468       17.9483
#   Standard LNN          2130.1699     2910.0820     780.7384      24345.4688    7541.6148
#   Advanced LNN          nan           nan           nan           nan           nan
#   Attention LNN         2139.9324     2917.7556     781.1308      24330.1367    7542.2389
#   CNN+LNN               2157.2917     2908.7024     777.5967      24319.3457    7540.7341
#   Transformer+LNN       2155.6172     2907.8171     801.0173      24277.1250    7535.3941
#   Bidir+LNN             2166.7258     2911.6643     776.5153      24367.5352    7555.6102
#
# Combined JSON → results/ukdale_eval/results_summary.json
# All graphs in  → results/ukdale_eval/

# %%
# ── Step 3: generate all graphs after all models done ──
# !python evaluate_on_ukdale.py --plot
# Out:
# Plot mode — loading saved results...
#   Loaded GRU from results/ukdale_eval/gru.json
#   Loaded LSTM from results/ukdale_eval/lstm.json
#   Loaded ResNet from results/ukdale_eval/resnet.json
#   Loaded TCN from results/ukdale_eval/tcn.json
#   Loaded Transformer from results/ukdale_eval/transformer.json
#   Loaded Standard LNN from results/ukdale_eval/standard_lnn.json
#   Loaded Advanced LNN from results/ukdale_eval/advanced_lnn.json
#   Loaded Attention LNN from results/ukdale_eval/attention_lnn.json
#   Loaded CNN+LNN from results/ukdale_eval/cnn_encoder.json
#   Loaded Transformer+LNN from results/ukdale_eval/transformer_lnn.json
#   Loaded Bidir+LNN from results/ukdale_eval/bidirectional_lnn.json
#
# Generating graphs...
#   Saved → results/ukdale_eval/mae_comparison.png
#   Saved → results/ukdale_eval/sae_comparison.png
#   Saved → results/ukdale_eval/f1_comparison.png
#
# ===========================================================================
#   F1 — Train: REDD  /  Test: UK-DALE
# ===========================================================================
#   Model                 Dish Washer   Fridge        Microwave     Washer Dryer  Avg
# ───────────────────────────────────────────────────────────────────────────
#   GRU                   0.0000        0.6225        0.0320        0.3815        0.2590
#   LSTM                  0.0869        0.5706        0.0000        0.2671        0.2312
#   ResNet                0.0094        0.5997        0.0437        0.1294        0.1956
#   TCN                   0.0614        0.6113        0.0382        0.2988        0.2524
#   Transformer           0.0793        0.7172        0.0297        0.3058        0.2830
#   Standard LNN          0.9710        0.9612        0.5952        0.2325        0.6900
#   Advanced LNN          0.0000        0.0000        0.0000        0.0000        0.0000
#   Attention LNN         0.9813        0.9704        0.5778        0.8901        0.8549
#   CNN+LNN               0.1674        0.9622        0.4753        0.9964        0.6503
#   Transformer+LNN       0.4972        0.9999        0.1697        0.9997        0.6666
#   Bidir+LNN             0.1119        0.9823        0.6302        0.2672        0.4979
#
# ===========================================================================
#   MAE — Train: REDD  /  Test: UK-DALE
# ===========================================================================
#   Model                 Dish Washer   Fridge        Microwave     Washer Dryer  Avg
# ───────────────────────────────────────────────────────────────────────────
#   GRU                   18.7102       48.5950       23.2031       36.6114       31.7799
#   LSTM                  23.8905       50.6561       7.7002        37.2581       29.8762
#   ResNet                25.1582       39.5930       38.7464       52.1681       38.9165
#   TCN                   18.7602       46.8484       9.0258        38.5928       28.3068
#   Transformer           19.1322       37.1403       12.4029       34.7747       25.8625
#   Standard LNN          2130.6350     2934.2258     793.9761      24340.4883    7549.8313
# /content/LNN/evaluate_on_ukdale.py:369: RuntimeWarning: Mean of empty slice
#   avg  = np.nanmean(vals)
#   Advanced LNN          nan           nan           nan           nan           nan
#   Attention LNN         2139.8513     2931.4846     797.0479      24332.4922    7550.2190
#   CNN+LNN               2156.8811     2931.4702     861.4076      24321.6855    7567.8611
#   Transformer+LNN       2155.1602     2930.6392     800.8639      24273.8965    7540.1399
#   Bidir+LNN             2166.3164     2930.4905     799.1103      24374.9473    7567.7161
#
# ===========================================================================
#   SAE — Train: REDD  /  Test: UK-DALE
# ===========================================================================
#   Model                 Dish Washer   Fridge        Microwave     Washer Dryer  Avg
# ───────────────────────────────────────────────────────────────────────────
#   GRU                   18.0481       32.2479       16.3138       29.6830       24.0732
#   LSTM                  21.1895       16.0117       5.8528        31.5198       18.6434
#   ResNet                22.2434       12.3050       32.0898       51.2197       29.4645
#   TCN                   18.0685       24.2782       5.8806        29.9081       19.5339
#   Transformer           18.0876       16.4157       6.4431        30.8468       17.9483
#   Standard LNN          2130.1699     2910.0820     780.7384      24345.4688    7541.6148
#   Advanced LNN          nan           nan           nan           nan           nan
#   Attention LNN         2139.9324     2917.7556     781.1308      24330.1367    7542.2389
#   CNN+LNN               2157.2917     2908.7024     777.5967      24319.3457    7540.7341
#   Transformer+LNN       2155.6172     2907.8171     801.0173      24277.1250    7535.3941
#   Bidir+LNN             2166.7258     2911.6643     776.5153      24367.5352    7555.6102
#
# Combined JSON → results/ukdale_eval/results_summary.json
# All graphs in  → results/ukdale_eval/
