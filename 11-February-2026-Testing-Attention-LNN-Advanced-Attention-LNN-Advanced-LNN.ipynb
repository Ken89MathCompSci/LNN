# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/kengoh-redd-data-change-runs-in-epoch/11-February-2026-Testing-Attention-LNN-Advanced-Attention-LNN-Advanced-LNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python run_attention_models.py
# Out:
# Attention-Enhanced Liquid Neural Network Comparison
# ...
#
# Testing appliance: dish washer
#
# This will train and compare 4 models:
#   1. Standard LNN (baseline)
#   2. Advanced LNN (multi-layer)
#   3. Attention LNN (single-layer + attention)
#   4. Advanced Attention LNN (multi-layer + attention)
#
# Configuration:
#   - Hidden size: 256
#   - Num layers: 3 (for multi-layer models)
#   - Learning rate: 0.001
#   - Epochs: 20 (with early stopping)
#
# Expected runtime: ~30-45 minutes with GPU
# ...
# Attention-Enhanced LNN Comparison on dish washer
# ...
#
# Using device: cuda
#
# Loading REDD dataset...
# Loading REDD data with specific splits...
# Train data shape: (28800, 5)
# Validation data shape: (28800, 5)
# Test data shape: (40059, 5)
# Train date range: 2011-04-21 19:41:24-04:00 to 2011-04-22 19:41:21-04:00
# Val date range: 2011-05-23 10:31:24-04:00 to 2011-05-24 10:31:21-04:00
# Test date range: 2011-04-18 09:22:12-04:00 to 2011-04-19 18:45:06-04:00
# ...
