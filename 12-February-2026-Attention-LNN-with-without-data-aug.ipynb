# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/LNN/blob/new-kengoh-test-attention-LNN-data-aug/12-February-2026-Attention-LNN-with-without-data-aug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_attention_liquidnn.py
# Out:
# Testing Attention-Enhanced Liquid Neural Networks on REDD dataset...
# ...
#
# ...
# TESTING: Attention LNN WITHOUT Data Augmentation (Baseline)
# ...
# Loading REDD data...
# Loading REDD data with specific splits...
#
# ...
# Testing attention_liquid on dish washer
# ...
#
# Random seed set to: 42
# Using device: cuda
# Creating sequences for dish washer...
# Input normalization: mean=529.05, std=917.25
# Training sequences: (5740, 100, 1) -> (5740, 1)
# Validation sequences: (5740, 100, 1) -> (5740, 1)
# Test sequences: (7992, 100, 1) -> (7992, 1)
# Model parameters: 396,033
# Starting attention_liquid training for dish washer...
# Epoch 1/20: 100% 180/180 [00:13<00:00, 13.14it/s, loss=3.46e+3]
# Epoch 1/20, Train Loss: 14966.965046, Val Loss: 13548.363446, Val MAE: 25.34, Val F1: 0.2696
# Model successfully saved to: models/attention_liquid_redd_specific_test_20260211_173054/dish_washer/attention_liquid_redd_dish_washer_best.pth
# ...
